# %% [markdown]
# # Visualizing word embeddings : Deep Learning for NLP embeddings.
#
# This notebook will guide you through the implementation of Word2Vec, a popular model used in Natural Language Processing (NLP) to capture semantic meaning from text. We will apply this model to a dataset and visualize the learned word embeddings.

# %% [markdown]
# <center><img src="https://education-team-2020.s3.eu-west-1.amazonaws.com/ai-eng/w4-s3/deep_learning.png" width="1000"/></center>

# %% [markdown]
# ## Tutorial
#
# In this notebook, we will apply the Word2Vec model to a text dataset. The Word2Vec model learns to represent words in a continuous vector space, where semantically similar words are mapped to nearby points. We will walk through the following steps:
#
# 1. **Download the Training Data:** We'll start by downloading a large text corpus for training.
# 2. **Set up Word2Vec in TensorFlow:** We'll configure the Word2Vec model using TensorFlow, a popular machine learning library.
# 3. **Train the Model:** We'll train the Word2Vec model on the dataset to learn word embeddings.
# 4. **Visualize the Embeddings:** Finally, we'll visualize the learned word embeddings using dimensionality reduction techniques.

# %%
reset -fs

# %%
# I like to live dangerously ☠
import warnings
warnings.filterwarnings('ignore')

# %%
import collections
import math
import os
from pprint import pprint
import random
import urllib.request
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf 
from sklearn.manifold import TSNE

# %matplotlib inline
# Out:
# 2024-08-16 23:17:33.793450: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Step 1: Download the Dataset
#
# To train our Word2Vec model, we need a large text corpus. In this step, we will download the "text8" dataset, a popular dataset used for training word embeddings. This dataset contains 100 MB of English Wikipedia text from 2006, which is commonly used in NLP tasks.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(path, filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    
    if not os.path.exists(path+filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    
    statinfo = os.stat(path+filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    
    return filename

path = ""
filename = maybe_download(path, 'text8.zip', 31_344_016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# > **Note:** While the dataset is being downloaded, feel free to look ahead at the upcoming code cells to get a sense of what we'll be doing next.

# %%
# Read the data into a list of strings.
def read_data(path, filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(path+filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_data(path, filename)
print('Dataset size: {:,} words'.format(len(vocabulary)))
# Out:
# Dataset size: 17,005,207 words

# %%
# Take a peak at the head
vocabulary[:20]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english']

# %% [markdown]
# ### Observations on Preprocessing
#
# - **Case and Punctuation:** Notice that none of the words in our dataset are capitalized, and there is no punctuation. This is likely due to preprocessing steps taken before we acquired the dataset, which ensures uniformity in the text.
# - **Preprocessing Considerations:** Preprocessing is a crucial part of NLP tasks, and its specifics depend on the data and the intended use. For instance, while we're working with unigrams (single words), other tasks might benefit from encoding n-grams (combinations of words) to capture context better.

# %% [markdown]
# -----
# Step 2: Build the dictionary
# -----

# %% [markdown]
# Now that we have our text data, the next step is to build a dictionary. This dictionary will map each unique word in our dataset to a unique integer code.
#
# Additionally, we'll keep track of the frequency of each word, which will help us prioritize the most common words.

# %%
vocabulary_size = 50_000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)

# %% [markdown]
# ### Understanding the Key Variables
#
# - **`data`:** A list of integer codes representing the words in the original text. Each word is replaced by its corresponding code from the `dictionary`.
# - **`count`:** A list of tuples where each tuple contains a word and its frequency count in the dataset.
# - **`dictionary`:** A dictionary mapping each word to its unique integer code.
# - **`reverse_dictionary`:** A reverse mapping that converts integer codes back to their corresponding words.

# %%
del vocabulary # Reduce memory by getting rid of the "heavy" list of strings

# %%
data[:5] # An index of each word (as it appears in order) to its rank. Therefore we don't have reference the string
# Out:
# [5234, 3081, 12, 6, 195]

# %%
dictionary['the'] # word: rank
# Out:
# 1

# %%
reverse_dictionary[5234] # rank: word
# Out:
# 'anarchism'

# %%
print('Most common words:') 
print(*count[:5], sep="\n")
# Out:
# Most common words:
# ['UNK', 418391]
# ('the', 1061396)
# ('of', 593677)
# ('and', 416629)
# ('one', 411764)

# %%
print('Least common words:')
print(*count[-5:], sep="\n")
# Out:
# Least common words:
# ('codeword', 9)
# ('senussi', 9)
# ('unscr', 9)
# ('leonards', 9)
# ('hif', 9)

# %% [markdown]
# ### Step 3: Generate a Training Batch for the Skip-Gram Model
#
# In this step, we'll create a function to generate training batches for our skip-gram model. The skip-gram model is a variant of Word2Vec that predicts the context words given a target word. This function will help us prepare the data in the correct format for training the model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer[:] = data[:span]
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, 
                               num_skips=2, 
                               skip_window=1)

# %%
# Example of self-supervised learning
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 2 of
# 195 term -> 6 a

# %% [markdown]
# ----
# Step 4: Build and train a skip-gram model.
# -----
#
# The Skip-Gram model is a type of neural network model used in Natural Language Processing (NLP) to learn distributed representations of words, commonly known as word embeddings.
#
# Word embeddings are dense vector representations of words that capture semantic relationships between them, meaning that words with similar meanings are mapped to similar points in the vector space.
#
# ### How the Skip-Gram Model Works
# The goal of the Skip-Gram model is to predict the context words given a target word. Here's how it works:
#
# Input: The model takes a single word (the target word) from the text as input.
#
# Output: The model is trained to predict words that are likely to appear in the context of the target word within a specified window of words before and after the target word. This context window is typically referred to as the "skip window."
#
# For example, if the sentence is "The cat sat on the mat," and the target word is "sat," the model might be asked to predict the words "The," "cat," "on," and "the," which appear around "sat."

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
import tensorflow.compat.v1 as v1

# %%
graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = v1.placeholder(tf.int32, shape=[batch_size])
    train_labels = v1.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = v1.constant(valid_examples, dtype=tf.int32)

    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            v1.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            v1.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Compute the average NCE loss for the batch.
        # tf.nce_loss automatically draws a new sample of the negative labels each
        # time we evaluate the loss.
        # Explanation of the meaning of NCE loss:
        #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
        loss = tf.reduce_mean(
          tf.nn.nce_loss(weights=nce_weights,
                         biases=nce_biases,
                         labels=train_labels,
                         inputs=embed,
                         num_sampled=num_sampled,
                         num_classes=vocabulary_size))

        # Construct the SGD optimizer using a learning rate of 1.0.
        optimizer = v1.train.GradientDescentOptimizer(1.0).minimize(loss)

        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(
          normalized_embeddings, valid_dataset)
        similarity = tf.matmul(
          valid_embeddings, normalized_embeddings, transpose_b=True)

        # Add variable initializer.
        init = v1.global_variables_initializer()

# %% [markdown]
# ----
# Step 5: Begin training.
# -----

# %%
num_steps = 100_001 #1 #2_001 #100_001

with v1.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2_000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 2_000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 4 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to '%s':" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
            print()
    final_embeddings = normalized_embeddings.eval()
# Out:
# 2024-08-16 23:18:21.593110: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# Initialized
# Average loss at step  0 :  286.0640563964844
# Nearest to 'they': guitar, infective, rlc, adm,
# Nearest to 'its': champaign, projection, cynicism, overtures,
# Nearest to 'but': retro, horizontal, militaristic, quieter,
# Nearest to 'while': rodan, typesetting, alderney, dictators,
# Nearest to 'zero': spawn, beli, antioxidants, disks,
# Nearest to 'world': diels, interned, aircraft, reports,
# Nearest to 'was': underworld, crimson, htm, contributors,
# Nearest to 'three': awarded, ample, explanations, badly,
# Nearest to 's': dianne, herzl, chocolat, cambodia,
# Nearest to 'no': fulltext, irt, antipope, elena,
# Nearest to 'known': selected, implicitly, reforming, becomes,
# Nearest to 'most': positrons, motorcycles, itchy, kayaks,
# Nearest to 'if': resonating, menlo, haemophilia, hyperthyroidism,
# Nearest to 'when': elaboration, messerschmitt, billion, slovenes,
# Nearest to 'over': compensation, attested, maggots, leg,
# Nearest to 'were': acquittal, yapese, euphoria, strapped,
#
# Average loss at step  2000 :  113.20361193799972
# Nearest to 'they': united, shall, spring, g,
# Nearest to 'its': jpg, projection, model, augustus,
# Nearest to 'but': humans, horizontal, alien, when,
# Nearest to 'while': government, score, knows, austroasiatic,
# Nearest to 'zero': vs, hermes, b, nine,
# Nearest to 'world': vs, aircraft, reports, dutch,
# Nearest to 'was': vs, community, consists, old,
# Nearest to 'three': awarded, states, vs, anthropology,
# Nearest to 's': railroad, amoeboid, consequence, cambodia,
# Nearest to 'no': sacred, aircraft, vs, animalium,
# Nearest to 'known': becomes, selected, evil, french,
# Nearest to 'most': final, led, run, trees,
# Nearest to 'if': eventual, particular, office, vs,
# Nearest to 'when': but, viewed, billion, identify,
# Nearest to 'over': springfield, attested, syndrome, leg,
# Nearest to 'were': astronomers, king, claims, census,
#
# Average loss at step  4000 :  52.71962926602364
# Nearest to 'they': shall, spring, worms, results,
# Nearest to 'its': robeson, jpg, model, agave,
# Nearest to 'but': horizontal, humans, carbon, alien,
# Nearest to 'while': binomial, government, base, knows,
# Nearest to 'zero': agave, nine, vs, basins,
# Nearest to 'world': aircraft, vs, reports, dutch,
# Nearest to 'was': in, and, gland, rifle,
# Nearest to 'three': basins, vs, awarded, agave,
# Nearest to 's': agave, cambodia, and, railroad,
# Nearest to 'no': sacred, travels, selected, var,
# Nearest to 'known': selected, gland, becomes, appellate,
# Nearest to 'most': var, final, led, run,
# Nearest to 'if': agave, eventual, extreme, legacy,
# Nearest to 'when': billion, but, intelligence, agave,
# Nearest to 'over': attested, springfield, bond, leg,
# Nearest to 'were': agave, king, respected, oxford,
#
# Average loss at step  6000 :  33.621938976287844
# Nearest to 'they': shall, worms, spring, producer,
# Nearest to 'its': robeson, jpg, model, agave,
# Nearest to 'but': horizontal, humans, when, carbon,
# Nearest to 'while': argentine, knows, caught, binomial,
# Nearest to 'zero': nine, agave, vs, ada,
# Nearest to 'world': aircraft, vs, dutch, reports,
# Nearest to 'was': in, is, hi, largely,
# Nearest to 'three': vs, basins, agave, manhattan,
# Nearest to 's': and, agave, cambodia, cite,
# Nearest to 'no': sacred, ptolemy, travels, downs,
# Nearest to 'known': selected, gland, galatians, evil,
# Nearest to 'most': var, led, trees, final,
# Nearest to 'if': agave, eventual, mosque, legacy,
# Nearest to 'when': billion, but, viewed, agave,
# Nearest to 'over': bond, attested, springfield, leg,
# Nearest to 'were': agave, king, respected, crew,
#
# Average loss at step  8000 :  23.4378579274416
# Nearest to 'they': guitar, shall, worms, results,
# Nearest to 'its': robeson, model, agave, projection,
# Nearest to 'but': horizontal, lymphoma, humans, when,
# Nearest to 'while': argentine, knows, caught, binomial,
# Nearest to 'zero': nine, coke, eight, archie,
# Nearest to 'world': aircraft, vs, reports, dutch,
# Nearest to 'was': is, in, and, coke,
# Nearest to 'three': vs, basins, agave, nine,
# Nearest to 's': and, agave, woe, shockwave,
# Nearest to 'no': frontal, sacred, kenya, travels,
# Nearest to 'known': selected, galatians, becomes, evil,
# Nearest to 'most': var, trees, run, final,
# Nearest to 'if': agave, hepatitis, eventual, legacy,
# Nearest to 'when': lymphoma, coke, but, billion,
# Nearest to 'over': bond, attested, springfield, compensation,
# Nearest to 'were': was, agave, king, respected,
#
# Average loss at step  10000 :  17.90175498855114
# Nearest to 'they': guitar, shall, it, adm,
# Nearest to 'its': agave, robeson, model, projection,
# Nearest to 'but': horizontal, lymphoma, and, when,
# Nearest to 'while': argentine, knows, caught, yeast,
# Nearest to 'zero': nine, eight, coke, archie,
# Nearest to 'world': reports, aircraft, vs, wozniak,
# Nearest to 'was': is, in, and, has,
# Nearest to 'three': vs, basins, zero, agave,
# Nearest to 's': and, the, agave, zero,
# Nearest to 'no': frontal, sacred, travels, kenya,
# Nearest to 'known': selected, becomes, galatians, evil,
# Nearest to 'most': var, trees, final, steps,
# Nearest to 'if': agave, hepatitis, defeating, eventual,
# Nearest to 'when': lymphoma, coke, but, billion,
# Nearest to 'over': bond, attested, leg, coke,
# Nearest to 'were': was, and, had, agave,
#
# Average loss at step  12000 :  14.148671652317047
# Nearest to 'they': guitar, it, adm, shall,
# Nearest to 'its': the, agave, matrices, model,
# Nearest to 'but': and, horizontal, lymphoma, when,
# Nearest to 'while': argentine, caught, knows, spalding,
# Nearest to 'zero': nine, eight, six, and,
# Nearest to 'world': reports, aircraft, vs, uses,
# Nearest to 'was': is, in, has, and,
# Nearest to 'three': nine, zero, vs, basins,
# Nearest to 's': and, the, zero, agave,
# Nearest to 'no': frontal, sacred, formalism, travels,
# Nearest to 'known': selected, galatians, becomes, implicitly,
# Nearest to 'most': var, trees, steps, final,
# Nearest to 'if': agave, defeating, hepatitis, eventual,
# Nearest to 'when': lymphoma, but, coke, billion,
# Nearest to 'over': bond, attested, leg, nile,
# Nearest to 'were': was, are, is, had,
#
# Average loss at step  14000 :  11.921675191283226
# Nearest to 'they': it, agouti, guitar, he,
# Nearest to 'its': the, agave, matrices, model,
# Nearest to 'but': agouti, and, horizontal, dasyprocta,
# Nearest to 'while': argentine, agouti, caught, yeast,
# Nearest to 'zero': nine, dasyprocta, agouti, eight,
# Nearest to 'world': dasyprocta, agouti, reports, vs,
# Nearest to 'was': is, agouti, has, coke,
# Nearest to 'three': agouti, nine, dasyprocta, zero,
# Nearest to 's': and, the, of, agouti,
# Nearest to 'no': frontal, formalism, travels, sacred,
# Nearest to 'known': selected, galatians, agouti, implicitly,
# Nearest to 'most': var, trees, dasyprocta, agouti,
# Nearest to 'if': agave, defeating, speculations, hepatitis,
# Nearest to 'when': agouti, lymphoma, but, coke,
# Nearest to 'over': agouti, bond, attested, leg,
# Nearest to 'were': are, was, and, had,
#
# Average loss at step  16000 :  10.002672465443611
# Nearest to 'they': he, it, agouti, guitar,
# Nearest to 'its': the, his, matrices, model,
# Nearest to 'but': and, agouti, dasyprocta, horizontal,
# Nearest to 'while': argentine, caught, agouti, yeast,
# Nearest to 'zero': nine, eight, six, five,
# Nearest to 'world': dasyprocta, agouti, reports, vs,
# Nearest to 'was': is, agouti, were, by,
# Nearest to 'three': nine, eight, zero, two,
# Nearest to 's': and, of, zero, the,
# Nearest to 'no': formalism, frontal, travels, kenya,
# Nearest to 'known': selected, galatians, agouti, appellate,
# Nearest to 'most': var, trees, cds, steps,
# Nearest to 'if': agave, defeating, speculations, when,
# Nearest to 'when': agouti, but, lymphoma, and,
# Nearest to 'over': agouti, bond, attested, leg,
# Nearest to 'were': are, and, was, had,
#
# Average loss at step  18000 :  8.532727939605714
# Nearest to 'they': he, it, agouti, guitar,
# Nearest to 'its': the, his, matrices, model,
# Nearest to 'but': and, agouti, dasyprocta, when,
# Nearest to 'while': argentine, caught, agouti, yeast,
# Nearest to 'zero': nine, eight, six, three,
# Nearest to 'world': dasyprocta, agouti, vs, reports,
# Nearest to 'was': is, were, by, has,
# Nearest to 'three': zero, nine, eight, two,
# Nearest to 's': and, zero, the, of,
# Nearest to 'no': antipope, formalism, frontal, travels,
# Nearest to 'known': selected, galatians, infancy, appellate,
# Nearest to 'most': var, trees, cds, steps,
# Nearest to 'if': agave, when, defeating, speculations,
# Nearest to 'when': agouti, but, lymphoma, was,
# Nearest to 'over': agouti, bond, attested, leg,
# Nearest to 'were': are, was, and, had,
#
# Average loss at step  20000 :  8.130032890319825
# Nearest to 'they': he, it, agouti, guitar,
# Nearest to 'its': the, his, matrices, proximity,
# Nearest to 'but': and, agouti, dasyprocta, when,
# Nearest to 'while': argentine, caught, agouti, spalding,
# Nearest to 'zero': nine, eight, five, six,
# Nearest to 'world': dasyprocta, agouti, vs, reports,
# Nearest to 'was': is, were, by, has,
# Nearest to 'three': zero, two, eight, nine,
# Nearest to 's': and, the, zero, his,
# Nearest to 'no': antipope, formalism, frontal, travels,
# Nearest to 'known': selected, galatians, agouti, archduke,
# Nearest to 'most': antiprism, var, trees, agouti,
# Nearest to 'if': agave, when, eagles, defeating,
# Nearest to 'when': agouti, but, lymphoma, was,
# Nearest to 'over': agouti, inappropriate, bond, attested,
# Nearest to 'were': are, was, had, is,
#
# Average loss at step  22000 :  6.942255160927773
# Nearest to 'they': he, it, agouti, not,
# Nearest to 'its': the, his, their, matrices,
# Nearest to 'but': and, agouti, sponsors, dasyprocta,
# Nearest to 'while': argentine, agouti, caught, spalding,
# Nearest to 'zero': eight, nine, six, five,
# Nearest to 'world': dasyprocta, agouti, uses, reports,
# Nearest to 'was': is, were, has, by,
# Nearest to 'three': eight, two, six, zero,
# Nearest to 's': and, the, his, zero,
# Nearest to 'no': antipope, formalism, frontal, a,
# Nearest to 'known': selected, galatians, archduke, agouti,
# Nearest to 'most': var, antiprism, trees, agouti,
# Nearest to 'if': agave, when, defeating, eagles,
# Nearest to 'when': but, agouti, was, and,
# Nearest to 'over': inappropriate, sponsors, agouti, attested,
# Nearest to 'were': are, was, had, is,
#
# Average loss at step  24000 :  6.789062440514565
# Nearest to 'they': he, it, not, agouti,
# Nearest to 'its': the, his, their, agave,
# Nearest to 'but': and, agouti, sponsors, dasyprocta,
# Nearest to 'while': argentine, agouti, caught, spalding,
# Nearest to 'zero': eight, nine, six, five,
# Nearest to 'world': dasyprocta, agouti, uses, reports,
# Nearest to 'was': is, were, has, by,
# Nearest to 'three': nine, eight, two, zero,
# Nearest to 's': and, two, his, zero,
# Nearest to 'no': antipope, formalism, frontal, travels,
# Nearest to 'known': selected, galatians, archduke, well,
# Nearest to 'most': var, antiprism, trees, agouti,
# Nearest to 'if': eagles, when, agave, defeating,
# Nearest to 'when': but, agouti, was, lymphoma,
# Nearest to 'over': inappropriate, agouti, sponsors, attested,
# Nearest to 'were': are, was, had, is,
#
# Average loss at step  26000 :  6.7098153595924375
# Nearest to 'they': he, it, not, agouti,
# Nearest to 'its': the, his, their, agave,
# Nearest to 'but': agouti, and, sponsors, dasyprocta,
# Nearest to 'while': argentine, agouti, caught, yeast,
# Nearest to 'zero': eight, three, six, five,
# Nearest to 'world': dasyprocta, agouti, uses, reports,
# Nearest to 'was': is, were, has, by,
# Nearest to 'three': eight, zero, seven, six,
# Nearest to 's': and, two, his, zero,
# Nearest to 'no': formalism, antipope, frontal, travels,
# Nearest to 'known': selected, galatians, archduke, agouti,
# Nearest to 'most': var, antiprism, agouti, trees,
# Nearest to 'if': when, eagles, agave, defeating,
# Nearest to 'when': but, agouti, was, six,
# Nearest to 'over': inappropriate, agouti, sponsors, attested,
# Nearest to 'were': are, was, had, by,
#
# Average loss at step  28000 :  6.347582849025726
# Nearest to 'they': he, it, not, who,
# Nearest to 'its': the, his, their, agave,
# Nearest to 'but': and, agouti, sponsors, dasyprocta,
# Nearest to 'while': argentine, agouti, caught, yeast,
# Nearest to 'zero': eight, six, five, three,
# Nearest to 'world': dasyprocta, aba, uses, agouti,
# Nearest to 'was': is, were, has, had,
# Nearest to 'three': eight, six, seven, five,
# Nearest to 's': and, the, his, zero,
# Nearest to 'no': formalism, antipope, frontal, travels,
# Nearest to 'known': selected, galatians, archduke, well,
# Nearest to 'most': var, antiprism, trees, imperium,
# Nearest to 'if': when, eagles, defeating, agave,
# Nearest to 'when': but, agouti, was, six,
# Nearest to 'over': inappropriate, agouti, sponsors, attested,
# Nearest to 'were': are, was, had, is,
#
# Average loss at step  30000 :  5.969282798051834
# Nearest to 'they': he, it, not, there,
# Nearest to 'its': the, his, their, agave,
# Nearest to 'but': and, agouti, dasyprocta, sponsors,
# Nearest to 'while': argentine, agouti, caught, spalding,
# Nearest to 'zero': five, eight, six, nine,
# Nearest to 'world': dasyprocta, diels, aba, uses,
# Nearest to 'was': is, were, has, had,
# Nearest to 'three': six, seven, eight, four,
# Nearest to 's': and, two, his, zero,
# Nearest to 'no': formalism, antipope, frontal, travels,
# Nearest to 'known': selected, galatians, well, archduke,
# Nearest to 'most': var, antiprism, imperium, trees,
# Nearest to 'if': when, eagles, defeating, agave,
# Nearest to 'when': but, agouti, six, if,
# Nearest to 'over': inappropriate, agouti, sponsors, attested,
# Nearest to 'were': are, was, had, by,
#
# Average loss at step  32000 :  5.987811906814575
# Nearest to 'they': he, it, not, there,
# Nearest to 'its': the, their, his, agave,
# Nearest to 'but': and, agouti, dasyprocta, sponsors,
# Nearest to 'while': argentine, agouti, caught, spalding,
# Nearest to 'zero': eight, five, six, nine,
# Nearest to 'world': dasyprocta, diels, aba, agouti,
# Nearest to 'was': is, were, has, had,
# Nearest to 'three': seven, six, five, four,
# Nearest to 's': and, the, his, two,
# Nearest to 'no': formalism, antipope, frontal, travels,
# Nearest to 'known': selected, archduke, well, galatians,
# Nearest to 'most': var, antiprism, imperium, trees,
# Nearest to 'if': when, eagles, defeating, agave,
# Nearest to 'when': but, agouti, if, six,
# Nearest to 'over': inappropriate, agouti, sponsors, attested,
# Nearest to 'were': are, was, by, had,
#
# Average loss at step  34000 :  5.670014519453049
# Nearest to 'they': he, it, not, there,
# Nearest to 'its': the, their, his, agave,
# Nearest to 'but': and, agouti, however, dasyprocta,
# Nearest to 'while': argentine, agm, agouti, yeast,
# Nearest to 'zero': five, eight, six, three,
# Nearest to 'world': dasyprocta, diels, aba, agouti,
# Nearest to 'was': is, were, has, had,
# Nearest to 'three': six, seven, five, four,
# Nearest to 's': and, two, his, agouti,
# Nearest to 'no': courtesan, formalism, a, antipope,
# Nearest to 'known': well, archduke, selected, galatians,
# Nearest to 'most': antiprism, var, imperium, trees,
# Nearest to 'if': when, eagles, defeating, agave,
# Nearest to 'when': but, agouti, if, and,
# Nearest to 'over': inappropriate, agouti, sponsors, circumnavigate,
# Nearest to 'were': are, was, had, by,
#
# Average loss at step  36000 :  5.73351345050335
# Nearest to 'they': he, it, there, not,
# Nearest to 'its': the, their, his, agave,
# Nearest to 'but': and, agouti, dasyprocta, however,
# Nearest to 'while': albury, argentine, agm, agouti,
# Nearest to 'zero': eight, five, six, seven,
# Nearest to 'world': dasyprocta, diels, aba, uses,
# Nearest to 'was': is, were, has, had,
# Nearest to 'three': seven, four, six, five,
# Nearest to 's': and, the, his, agouti,
# Nearest to 'no': courtesan, formalism, antipope, frontal,
# Nearest to 'known': well, archduke, selected, galatians,
# Nearest to 'most': antiprism, var, imperium, trees,
# Nearest to 'if': when, eagles, defeating, agave,
# Nearest to 'when': but, agouti, and, if,
# Nearest to 'over': agouti, inappropriate, sponsors, albury,
# Nearest to 'were': are, was, had, by,
#
# Average loss at step  38000 :  5.512344720840454
# Nearest to 'they': he, it, there, not,
# Nearest to 'its': their, the, his, agave,
# Nearest to 'but': agouti, however, dasyprocta, and,
# Nearest to 'while': albury, argentine, agm, agouti,
# Nearest to 'zero': eight, five, six, four,
# Nearest to 'world': dasyprocta, diels, aba, uses,
# Nearest to 'was': is, were, has, had,
# Nearest to 'three': four, five, six, seven,
# Nearest to 's': the, and, his, agouti,
# Nearest to 'no': courtesan, formalism, antipope, a,
# Nearest to 'known': well, archduke, selected, wears,
# Nearest to 'most': antiprism, var, imperium, advice,
# Nearest to 'if': when, eagles, defeating, but,
# Nearest to 'when': but, agouti, if, six,
# Nearest to 'over': agouti, inappropriate, sponsors, circumnavigate,
# Nearest to 'were': are, was, had, is,
#
# Average loss at step  40000 :  5.278297510743141
# Nearest to 'they': he, it, there, not,
# Nearest to 'its': their, the, his, agave,
# Nearest to 'but': agouti, and, however, dasyprocta,
# Nearest to 'while': albury, argentine, agm, agouti,
# Nearest to 'zero': eight, five, six, four,
# Nearest to 'world': diels, dasyprocta, uses, aba,
# Nearest to 'was': is, were, has, had,
# Nearest to 'three': four, five, seven, six,
# Nearest to 's': his, zero, the, and,
# Nearest to 'no': courtesan, formalism, antipope, frontal,
# Nearest to 'known': well, archduke, selected, galatians,
# Nearest to 'most': antiprism, var, agouti, advice,
# Nearest to 'if': when, eagles, defeating, agave,
# Nearest to 'when': but, if, agouti, six,
# Nearest to 'over': inappropriate, agouti, sponsors, circumnavigate,
# Nearest to 'were': are, was, had, is,
#
# Average loss at step  42000 :  5.357700305461884
# Nearest to 'they': he, it, there, not,
# Nearest to 'its': their, his, the, agave,
# Nearest to 'but': and, agouti, however, dasyprocta,
# Nearest to 'while': albury, argentine, agm, agouti,
# Nearest to 'zero': five, eight, six, seven,
# Nearest to 'world': diels, dasyprocta, republic, uses,
# Nearest to 'was': is, were, has, had,
# Nearest to 'three': four, five, six, seven,
# Nearest to 's': his, and, agouti, dasyprocta,
# Nearest to 'no': courtesan, formalism, antipope, frontal,
# Nearest to 'known': well, archduke, selected, wears,
# Nearest to 'most': antiprism, var, advice, imperium,
# Nearest to 'if': when, eagles, defeating, agave,
# Nearest to 'when': agouti, but, if, six,
# Nearest to 'over': agouti, sponsors, inappropriate, albury,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  44000 :  5.232381311893463
# Nearest to 'they': he, it, there, not,
# Nearest to 'its': their, the, his, robeson,
# Nearest to 'but': and, agouti, however, sponsors,
# Nearest to 'while': albury, argentine, agouti, agm,
# Nearest to 'zero': eight, five, six, nine,
# Nearest to 'world': diels, dasyprocta, republic, aba,
# Nearest to 'was': is, were, has, had,
# Nearest to 'three': five, four, six, seven,
# Nearest to 's': his, and, the, three,
# Nearest to 'no': courtesan, formalism, antipope, frontal,
# Nearest to 'known': well, archduke, selected, wears,
# Nearest to 'most': antiprism, var, imperium, agouti,
# Nearest to 'if': when, eagles, defeating, agave,
# Nearest to 'when': if, agouti, but, six,
# Nearest to 'over': inappropriate, agouti, sponsors, circumnavigate,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  46000 :  5.245139038443566
# Nearest to 'they': he, there, it, you,
# Nearest to 'its': their, his, the, robeson,
# Nearest to 'but': and, agouti, however, dasyprocta,
# Nearest to 'while': albury, argentine, agouti, and,
# Nearest to 'zero': eight, five, six, nine,
# Nearest to 'world': dasyprocta, diels, agouti, aba,
# Nearest to 'was': is, were, has, had,
# Nearest to 'three': five, four, two, six,
# Nearest to 's': his, and, agouti, cyclic,
# Nearest to 'no': courtesan, formalism, a, antipope,
# Nearest to 'known': archduke, well, selected, wears,
# Nearest to 'most': antiprism, var, imperium, agouti,
# Nearest to 'if': when, eagles, defeating, but,
# Nearest to 'when': but, agouti, and, if,
# Nearest to 'over': agouti, sponsors, inappropriate, circumnavigate,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  48000 :  5.236904027938842
# Nearest to 'they': he, there, it, you,
# Nearest to 'its': their, his, the, robeson,
# Nearest to 'but': and, agouti, however, dasyprocta,
# Nearest to 'while': albury, argentine, agouti, since,
# Nearest to 'zero': eight, nine, six, five,
# Nearest to 'world': diels, dasyprocta, aba, uses,
# Nearest to 'was': is, were, had, has,
# Nearest to 'three': four, five, six, seven,
# Nearest to 's': his, and, zero, agouti,
# Nearest to 'no': courtesan, formalism, a, antipope,
# Nearest to 'known': well, archduke, selected, wears,
# Nearest to 'most': antiprism, var, agouti, imperium,
# Nearest to 'if': when, eagles, defeating, agave,
# Nearest to 'when': if, but, agouti, and,
# Nearest to 'over': inappropriate, agouti, sponsors, circumnavigate,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  50000 :  4.994686614632607
# Nearest to 'they': he, there, you, it,
# Nearest to 'its': their, his, the, robeson,
# Nearest to 'but': and, however, agouti, dasyprocta,
# Nearest to 'while': albury, argentine, agouti, for,
# Nearest to 'zero': eight, five, seven, six,
# Nearest to 'world': diels, dasyprocta, agouti, aba,
# Nearest to 'was': is, were, has, had,
# Nearest to 'three': four, five, seven, six,
# Nearest to 's': his, and, of, zero,
# Nearest to 'no': courtesan, formalism, antipope, a,
# Nearest to 'known': well, archduke, selected, wears,
# Nearest to 'most': antiprism, var, trees, imperium,
# Nearest to 'if': when, eagles, defeating, while,
# Nearest to 'when': if, and, but, agouti,
# Nearest to 'over': agouti, inappropriate, sponsors, circumnavigate,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  52000 :  5.025877690196038
# Nearest to 'they': he, there, you, it,
# Nearest to 'its': their, his, the, robeson,
# Nearest to 'but': and, however, agouti, dasyprocta,
# Nearest to 'while': albury, argentine, agouti, since,
# Nearest to 'zero': eight, five, nine, six,
# Nearest to 'world': diels, uses, dasyprocta, huggins,
# Nearest to 'was': is, were, has, had,
# Nearest to 'three': four, five, two, six,
# Nearest to 's': his, and, cyclic, of,
# Nearest to 'no': courtesan, formalism, antipope, a,
# Nearest to 'known': well, archduke, selected, wears,
# Nearest to 'most': antiprism, var, ursus, agouti,
# Nearest to 'if': when, but, defeating, while,
# Nearest to 'when': if, agouti, but, and,
# Nearest to 'over': agouti, inappropriate, sponsors, circumnavigate,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  54000 :  5.190672221302986
# Nearest to 'they': he, there, it, you,
# Nearest to 'its': their, his, the, robeson,
# Nearest to 'but': however, and, agouti, dasyprocta,
# Nearest to 'while': albury, argentine, agouti, since,
# Nearest to 'zero': eight, six, five, nine,
# Nearest to 'world': diels, uses, dasyprocta, republic,
# Nearest to 'was': is, were, has, had,
# Nearest to 'three': five, two, six, four,
# Nearest to 's': his, zero, cyclic, and,
# Nearest to 'no': courtesan, formalism, antipope, a,
# Nearest to 'known': well, archduke, selected, wears,
# Nearest to 'most': antiprism, more, var, ursus,
# Nearest to 'if': when, but, eagles, defeating,
# Nearest to 'when': if, but, agouti, and,
# Nearest to 'over': inappropriate, sponsors, agouti, circumnavigate,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  56000 :  5.068837879657745
# Nearest to 'they': he, there, you, it,
# Nearest to 'its': their, his, the, robeson,
# Nearest to 'but': however, and, agouti, dasyprocta,
# Nearest to 'while': albury, argentine, agouti, but,
# Nearest to 'zero': six, eight, five, seven,
# Nearest to 'world': diels, dasyprocta, uses, agouti,
# Nearest to 'was': is, has, were, had,
# Nearest to 'three': four, five, six, two,
# Nearest to 's': his, zero, cyclic, and,
# Nearest to 'no': courtesan, formalism, antipope, hounds,
# Nearest to 'known': well, archduke, selected, wears,
# Nearest to 'most': antiprism, more, var, trees,
# Nearest to 'if': when, but, while, eagles,
# Nearest to 'when': if, and, but, agouti,
# Nearest to 'over': inappropriate, sponsors, agouti, circumnavigate,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  58000 :  5.070266503095627
# Nearest to 'they': he, there, you, it,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, dasyprocta,
# Nearest to 'while': albury, argentine, agouti, although,
# Nearest to 'zero': six, eight, seven, five,
# Nearest to 'world': diels, dasyprocta, uses, republic,
# Nearest to 'was': is, has, had, were,
# Nearest to 'three': four, five, two, six,
# Nearest to 's': his, cyclic, and, zero,
# Nearest to 'no': courtesan, formalism, a, antipope,
# Nearest to 'known': well, archduke, selected, wears,
# Nearest to 'most': more, antiprism, var, trees,
# Nearest to 'if': when, but, while, defeating,
# Nearest to 'when': if, but, agouti, and,
# Nearest to 'over': agouti, sponsors, inappropriate, four,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  60000 :  4.939685839891434
# Nearest to 'they': he, there, you, it,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, agouti, and, dasyprocta,
# Nearest to 'while': albury, argentine, pulau, but,
# Nearest to 'zero': six, eight, seven, five,
# Nearest to 'world': diels, dasyprocta, uses, agouti,
# Nearest to 'was': is, had, has, were,
# Nearest to 'three': four, five, two, six,
# Nearest to 's': and, his, cyclic, agouti,
# Nearest to 'no': courtesan, formalism, antipope, hounds,
# Nearest to 'known': well, archduke, selected, wears,
# Nearest to 'most': antiprism, more, var, advice,
# Nearest to 'if': when, but, while, eagles,
# Nearest to 'when': if, but, agouti, six,
# Nearest to 'over': agouti, sponsors, inappropriate, five,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  62000 :  5.017626127123832
# Nearest to 'they': he, there, you, it,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, dasyprocta,
# Nearest to 'while': albury, argentine, pulau, but,
# Nearest to 'zero': eight, six, five, seven,
# Nearest to 'world': diels, dasyprocta, uses, republic,
# Nearest to 'was': is, had, has, were,
# Nearest to 'three': five, four, six, two,
# Nearest to 's': his, and, cyclic, agouti,
# Nearest to 'no': courtesan, formalism, antipope, hounds,
# Nearest to 'known': well, archduke, selected, wears,
# Nearest to 'most': more, antiprism, many, var,
# Nearest to 'if': when, while, but, eagles,
# Nearest to 'when': if, but, agouti, since,
# Nearest to 'over': agouti, sponsors, inappropriate, circumnavigate,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  64000 :  4.843605765998364
# Nearest to 'they': he, there, you, it,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, agouti, and, dasyprocta,
# Nearest to 'while': albury, pulau, agouti, argentine,
# Nearest to 'zero': eight, six, seven, five,
# Nearest to 'world': diels, dasyprocta, republic, uses,
# Nearest to 'was': is, had, has, were,
# Nearest to 'three': five, four, six, two,
# Nearest to 's': his, and, cyclic, agouti,
# Nearest to 'no': formalism, courtesan, antipope, keeping,
# Nearest to 'known': well, archduke, selected, wears,
# Nearest to 'most': more, antiprism, many, var,
# Nearest to 'if': when, while, but, eagles,
# Nearest to 'when': if, but, agouti, since,
# Nearest to 'over': agouti, sponsors, inappropriate, four,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  66000 :  4.587689897179604
# Nearest to 'they': he, there, you, it,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, agouti, and, dasyprocta,
# Nearest to 'while': albury, but, pulau, although,
# Nearest to 'zero': six, eight, seven, five,
# Nearest to 'world': diels, republic, dasyprocta, uses,
# Nearest to 'was': is, had, has, were,
# Nearest to 'three': five, four, six, two,
# Nearest to 's': his, cyclic, dasyprocta, agouti,
# Nearest to 'no': formalism, courtesan, antipope, keeping,
# Nearest to 'known': well, archduke, selected, wears,
# Nearest to 'most': upanija, more, antiprism, many,
# Nearest to 'if': when, while, but, eagles,
# Nearest to 'when': if, but, agouti, since,
# Nearest to 'over': agouti, inappropriate, sponsors, four,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  68000 :  4.9824735847711565
# Nearest to 'they': he, there, you, it,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, dasyprocta,
# Nearest to 'while': albury, thaler, but, although,
# Nearest to 'zero': eight, six, five, seven,
# Nearest to 'world': diels, dasyprocta, republic, uses,
# Nearest to 'was': is, had, has, were,
# Nearest to 'three': five, four, six, two,
# Nearest to 's': his, cyclic, zero, agouti,
# Nearest to 'no': formalism, courtesan, keeping, hounds,
# Nearest to 'known': well, archduke, selected, such,
# Nearest to 'most': more, many, upanija, antiprism,
# Nearest to 'if': when, while, defeating, but,
# Nearest to 'when': if, but, agouti, since,
# Nearest to 'over': agouti, inappropriate, sponsors, circumnavigate,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  70000 :  4.889037759780884
# Nearest to 'they': he, there, you, it,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, or,
# Nearest to 'while': albury, thaler, but, although,
# Nearest to 'zero': eight, five, six, seven,
# Nearest to 'world': diels, republic, dasyprocta, uses,
# Nearest to 'was': is, had, has, were,
# Nearest to 'three': five, four, six, eight,
# Nearest to 's': his, and, cyclic, refueling,
# Nearest to 'no': formalism, courtesan, antipope, keeping,
# Nearest to 'known': well, archduke, selected, such,
# Nearest to 'most': more, upanija, antiprism, many,
# Nearest to 'if': when, while, but, though,
# Nearest to 'when': if, but, agouti, since,
# Nearest to 'over': agouti, inappropriate, sponsors, circumnavigate,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  72000 :  4.7428207352161404
# Nearest to 'they': he, there, you, it,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, dasyprocta,
# Nearest to 'while': albury, but, thaler, although,
# Nearest to 'zero': eight, five, six, seven,
# Nearest to 'world': diels, dasyprocta, republic, agouti,
# Nearest to 'was': is, had, has, were,
# Nearest to 'three': five, four, six, two,
# Nearest to 's': his, and, cyclic, agouti,
# Nearest to 'no': formalism, courtesan, accumulator, antipope,
# Nearest to 'known': well, archduke, such, selected,
# Nearest to 'most': more, upanija, antiprism, many,
# Nearest to 'if': when, while, though, defeating,
# Nearest to 'when': if, agouti, but, since,
# Nearest to 'over': agouti, inappropriate, sponsors, circumnavigate,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  74000 :  4.812519575595855
# Nearest to 'they': he, there, you, it,
# Nearest to 'its': their, the, his, michelob,
# Nearest to 'but': however, and, agouti, dasyprocta,
# Nearest to 'while': albury, thaler, but, although,
# Nearest to 'zero': five, eight, six, four,
# Nearest to 'world': diels, republic, dasyprocta, huggins,
# Nearest to 'was': is, had, has, were,
# Nearest to 'three': five, four, six, two,
# Nearest to 's': his, and, cyclic, agouti,
# Nearest to 'no': courtesan, formalism, a, antipope,
# Nearest to 'known': well, archduke, such, selected,
# Nearest to 'most': more, upanija, antiprism, many,
# Nearest to 'if': when, while, defeating, for,
# Nearest to 'when': if, but, agouti, because,
# Nearest to 'over': inappropriate, agouti, circumnavigate, sponsors,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  76000 :  4.722892417430877
# Nearest to 'they': he, there, you, we,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, agouti, and, dasyprocta,
# Nearest to 'while': albury, but, thaler, although,
# Nearest to 'zero': eight, five, six, four,
# Nearest to 'world': diels, dasyprocta, huggins, agouti,
# Nearest to 'was': is, had, were, has,
# Nearest to 'three': five, four, six, two,
# Nearest to 's': his, cyclic, refueling, orchid,
# Nearest to 'no': courtesan, formalism, a, antipope,
# Nearest to 'known': well, archduke, such, selected,
# Nearest to 'most': more, upanija, antiprism, many,
# Nearest to 'if': when, while, defeating, agave,
# Nearest to 'when': if, but, agouti, because,
# Nearest to 'over': agouti, inappropriate, sponsors, circumnavigate,
# Nearest to 'were': are, was, had, have,
#
# Average loss at step  78000 :  4.784711600631476
# Nearest to 'they': he, there, you, we,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, agouti, and, dasyprocta,
# Nearest to 'while': albury, but, thaler, although,
# Nearest to 'zero': five, eight, six, seven,
# Nearest to 'world': diels, dasyprocta, agouti, republic,
# Nearest to 'was': is, had, were, has,
# Nearest to 'three': five, six, four, two,
# Nearest to 's': his, cyclic, agouti, dasyprocta,
# Nearest to 'no': courtesan, formalism, antipope, a,
# Nearest to 'known': well, archduke, used, such,
# Nearest to 'most': more, many, upanija, antiprism,
# Nearest to 'if': when, while, defeating, though,
# Nearest to 'when': if, but, because, agouti,
# Nearest to 'over': agouti, inappropriate, sponsors, circumnavigate,
# Nearest to 'were': are, had, was, have,
#
# Average loss at step  80000 :  4.792739159703254
# Nearest to 'they': he, there, you, we,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, dasyprocta,
# Nearest to 'while': but, albury, although, thaler,
# Nearest to 'zero': five, four, six, eight,
# Nearest to 'world': diels, iit, dasyprocta, republic,
# Nearest to 'was': is, had, were, has,
# Nearest to 'three': five, six, four, two,
# Nearest to 's': his, busan, cyclic, zero,
# Nearest to 'no': courtesan, formalism, antipope, hounds,
# Nearest to 'known': well, archduke, used, such,
# Nearest to 'most': more, many, upanija, antiprism,
# Nearest to 'if': when, though, defeating, eagles,
# Nearest to 'when': if, agouti, because, but,
# Nearest to 'over': agouti, sponsors, inappropriate, determinative,
# Nearest to 'were': are, had, was, have,
#
# Average loss at step  82000 :  4.755909363150597
# Nearest to 'they': he, there, you, we,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, dasyprocta,
# Nearest to 'while': but, albury, although, thaler,
# Nearest to 'zero': eight, five, four, six,
# Nearest to 'world': diels, iit, dasyprocta, huggins,
# Nearest to 'was': is, had, were, has,
# Nearest to 'three': five, six, four, two,
# Nearest to 's': busan, his, agouti, zero,
# Nearest to 'no': courtesan, formalism, antipope, accumulator,
# Nearest to 'known': well, archduke, used, such,
# Nearest to 'most': more, many, upanija, some,
# Nearest to 'if': when, though, while, where,
# Nearest to 'when': if, agouti, because, since,
# Nearest to 'over': agouti, inappropriate, sponsors, determinative,
# Nearest to 'were': are, had, was, have,
#
# Average loss at step  84000 :  4.745693093180656
# Nearest to 'they': he, there, you, we,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, or,
# Nearest to 'while': but, albury, although, however,
# Nearest to 'zero': five, eight, six, seven,
# Nearest to 'world': diels, iit, dasyprocta, huggins,
# Nearest to 'was': is, had, were, has,
# Nearest to 'three': five, four, six, two,
# Nearest to 's': his, busan, zero, agouti,
# Nearest to 'no': formalism, courtesan, antipope, accumulator,
# Nearest to 'known': well, archduke, used, such,
# Nearest to 'most': more, many, some, upanija,
# Nearest to 'if': when, though, while, defeating,
# Nearest to 'when': if, agouti, but, where,
# Nearest to 'over': agouti, sponsors, inappropriate, duplicates,
# Nearest to 'were': are, had, was, have,
#
# Average loss at step  86000 :  4.773068067908287
# Nearest to 'they': he, there, you, we,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, which,
# Nearest to 'while': but, albury, although, however,
# Nearest to 'zero': five, eight, six, seven,
# Nearest to 'world': iit, diels, dasyprocta, agouti,
# Nearest to 'was': is, had, were, has,
# Nearest to 'three': four, five, two, six,
# Nearest to 's': busan, his, five, agouti,
# Nearest to 'no': courtesan, formalism, antipope, a,
# Nearest to 'known': well, used, archduke, such,
# Nearest to 'most': more, many, upanija, some,
# Nearest to 'if': when, though, while, agave,
# Nearest to 'when': if, agouti, but, after,
# Nearest to 'over': agouti, duplicates, sponsors, determinative,
# Nearest to 'were': are, had, was, have,
#
# Average loss at step  88000 :  4.754999238729477
# Nearest to 'they': there, he, you, we,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, which,
# Nearest to 'while': but, although, albury, and,
# Nearest to 'zero': five, eight, seven, six,
# Nearest to 'world': diels, iit, huggins, dasyprocta,
# Nearest to 'was': is, had, were, has,
# Nearest to 'three': four, five, two, six,
# Nearest to 's': his, busan, agouti, dasyprocta,
# Nearest to 'no': formalism, courtesan, antipope, accumulator,
# Nearest to 'known': well, used, archduke, such,
# Nearest to 'most': more, many, some, upanija,
# Nearest to 'if': when, though, while, where,
# Nearest to 'when': if, agouti, where, but,
# Nearest to 'over': agouti, determinative, duplicates, sponsors,
# Nearest to 'were': are, had, was, have,
#
# Average loss at step  90000 :  4.750420444846153
# Nearest to 'they': he, there, you, we,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, which,
# Nearest to 'while': but, however, albury, although,
# Nearest to 'zero': five, eight, seven, six,
# Nearest to 'world': diels, iit, huggins, dasyprocta,
# Nearest to 'was': is, had, has, were,
# Nearest to 'three': five, four, two, six,
# Nearest to 's': his, and, busan, agouti,
# Nearest to 'no': courtesan, formalism, any, antipope,
# Nearest to 'known': well, used, archduke, such,
# Nearest to 'most': more, many, some, upanija,
# Nearest to 'if': when, though, while, where,
# Nearest to 'when': if, after, because, where,
# Nearest to 'over': agouti, determinative, sponsors, duplicates,
# Nearest to 'were': are, had, have, was,
#
# Average loss at step  92000 :  4.6628129469156265
# Nearest to 'they': there, he, you, we,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, or,
# Nearest to 'while': but, however, although, albury,
# Nearest to 'zero': five, eight, seven, six,
# Nearest to 'world': iit, diels, dasyprocta, huggins,
# Nearest to 'was': is, had, has, were,
# Nearest to 'three': five, two, four, seven,
# Nearest to 's': his, busan, and, agouti,
# Nearest to 'no': courtesan, formalism, any, antipope,
# Nearest to 'known': well, used, archduke, such,
# Nearest to 'most': more, many, some, upanija,
# Nearest to 'if': when, though, while, where,
# Nearest to 'when': if, after, because, agouti,
# Nearest to 'over': determinative, agouti, sponsors, duplicates,
# Nearest to 'were': are, had, have, was,
#
# Average loss at step  94000 :  4.721879860758781
# Nearest to 'they': there, he, we, you,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, which,
# Nearest to 'while': but, although, however, albury,
# Nearest to 'zero': seven, eight, five, six,
# Nearest to 'world': diels, iit, dasyprocta, huggins,
# Nearest to 'was': is, had, has, were,
# Nearest to 'three': five, two, four, seven,
# Nearest to 's': his, busan, and, agouti,
# Nearest to 'no': courtesan, formalism, any, accumulator,
# Nearest to 'known': well, used, archduke, such,
# Nearest to 'most': more, many, some, upanija,
# Nearest to 'if': when, though, where, while,
# Nearest to 'when': if, agouti, after, because,
# Nearest to 'over': determinative, sponsors, duplicates, agouti,
# Nearest to 'were': are, had, have, was,
#
# Average loss at step  96000 :  4.696141667485237
# Nearest to 'they': there, he, we, you,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, or,
# Nearest to 'while': but, however, although, albury,
# Nearest to 'zero': eight, five, six, seven,
# Nearest to 'world': iit, dasyprocta, diels, huggins,
# Nearest to 'was': is, had, has, were,
# Nearest to 'three': five, four, two, six,
# Nearest to 's': his, and, busan, agouti,
# Nearest to 'no': any, courtesan, formalism, accumulator,
# Nearest to 'known': well, used, archduke, such,
# Nearest to 'most': more, many, some, upanija,
# Nearest to 'if': when, though, where, while,
# Nearest to 'when': if, because, after, agouti,
# Nearest to 'over': determinative, agouti, sponsors, duplicates,
# Nearest to 'were': are, had, was, have,
#
# Average loss at step  98000 :  4.596550449848175
# Nearest to 'they': he, there, you, we,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, which,
# Nearest to 'while': but, however, although, albury,
# Nearest to 'zero': eight, five, seven, six,
# Nearest to 'world': iit, diels, dasyprocta, huggins,
# Nearest to 'was': is, has, had, were,
# Nearest to 'three': five, four, two, six,
# Nearest to 's': busan, agouti, dasyprocta, his,
# Nearest to 'no': courtesan, any, formalism, accumulator,
# Nearest to 'known': used, well, archduke, such,
# Nearest to 'most': more, many, some, upanija,
# Nearest to 'if': when, though, while, where,
# Nearest to 'when': if, after, because, agouti,
# Nearest to 'over': determinative, sponsors, agouti, benchers,
# Nearest to 'were': are, had, have, was,
#
# Average loss at step  100000 :  4.6995703723430635
# Nearest to 'they': he, there, you, we,
# Nearest to 'its': their, his, the, michelob,
# Nearest to 'but': however, and, agouti, thaler,
# Nearest to 'while': but, however, although, albury,
# Nearest to 'zero': eight, five, seven, nine,
# Nearest to 'world': iit, dasyprocta, diels, huggins,
# Nearest to 'was': is, had, has, were,
# Nearest to 'three': five, four, two, seven,
# Nearest to 's': his, busan, agouti, cyclic,
# Nearest to 'no': any, courtesan, formalism, accumulator,
# Nearest to 'known': used, well, such, archduke,
# Nearest to 'most': more, many, some, upanija,
# Nearest to 'if': when, though, while, where,
# Nearest to 'when': if, after, because, where,
# Nearest to 'over': determinative, agouti, sponsors, benchers,
# Nearest to 'were': are, had, have, was,

# %% [markdown]
# <center><img src="../images/watiing.jpg" width="700"/></center>

# %% [markdown]
# -----
# Step 6: Visualize the embeddings with t-SNE.
# ----

# %% [markdown]
# In this step, we use the t-SNE algorithm to reduce the dimensionality of the learned word embeddings for visualization.
#
# The top 500 words (based on frequency) are plotted in a 2D space, allowing us to visually inspect the relationships and groupings among words.
#
# This visualization is a powerful tool to understand how well the model has learned semantic relationships.

# %%
tsne = TSNE(perplexity=30, 
            n_components=2, 
            init='pca', 
            n_iter=5_000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]

n_words_to_visualize = 40

for i, label in enumerate(labels[:n_words_to_visualize]):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %% [markdown]
# ------
#
# # Let's render and plot more samples.

# %%
def plot_with_labels(low_dim_embs, labels, filename='../images/tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels)

# %% [markdown]
# # And voila!
#
# Now you have a visual understanding of embeddings.

# %% [markdown]
# Thank you for following this tutorial!
