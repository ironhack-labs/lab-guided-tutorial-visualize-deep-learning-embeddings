# %% [markdown]
# # Visualizing word embeddings : Deep Learning for NLP embeddings.
#
# This notebook will guide you through the implementation of Word2Vec, a popular model used in Natural Language Processing (NLP) to capture semantic meaning from text. We will apply this model to a dataset and visualize the learned word embeddings.

# %% [markdown]
# <center><img src="https://education-team-2020.s3.eu-west-1.amazonaws.com/ai-eng/w4-s3/deep_learning.png" width="1000"/></center>

# %% [markdown]
# ## Tutorial
#
# In this notebook, we will apply the Word2Vec model to a text dataset. The Word2Vec model learns to represent words in a continuous vector space, where semantically similar words are mapped to nearby points. We will walk through the following steps:
#
# 1. **Download the Training Data:** We'll start by downloading a large text corpus for training.
# 2. **Set up Word2Vec in TensorFlow:** We'll configure the Word2Vec model using TensorFlow, a popular machine learning library.
# 3. **Train the Model:** We'll train the Word2Vec model on the dataset to learn word embeddings.
# 4. **Visualize the Embeddings:** Finally, we'll visualize the learned word embeddings using dimensionality reduction techniques.

# %%
reset -fs

# %%
# I like to live dangerously ☠
import warnings
warnings.filterwarnings('ignore')

# %%
import collections
import math
import os
from pprint import pprint
import random
import urllib.request
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf 
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# ### Step 1: Download the Dataset
#
# To train our Word2Vec model, we need a large text corpus. In this step, we will download the "text8" dataset, a popular dataset used for training word embeddings. This dataset contains 100 MB of English Wikipedia text from 2006, which is commonly used in NLP tasks.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(path, filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    
    if not os.path.exists(path+filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    
    statinfo = os.stat(path+filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    
    return filename

path = ""
filename = maybe_download(path, 'text8.zip', 31_344_016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# > **Note:** While the dataset is being downloaded, feel free to look ahead at the upcoming code cells to get a sense of what we'll be doing next.

# %%
# Read the data into a list of strings.
def read_data(path, filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(path+filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_data(path, filename)
print('Dataset size: {:,} words'.format(len(vocabulary)))
# Out:
# Dataset size: 17,005,207 words

# %%
# Take a peak at the head
vocabulary[:20]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english']

# %% [markdown]
# ### Observations on Preprocessing
#
# - **Case and Punctuation:** Notice that none of the words in our dataset are capitalized, and there is no punctuation. This is likely due to preprocessing steps taken before we acquired the dataset, which ensures uniformity in the text.
# - **Preprocessing Considerations:** Preprocessing is a crucial part of NLP tasks, and its specifics depend on the data and the intended use. For instance, while we're working with unigrams (single words), other tasks might benefit from encoding n-grams (combinations of words) to capture context better.

# %% [markdown]
# -----
# Step 2: Build the dictionary
# -----

# %% [markdown]
# Now that we have our text data, the next step is to build a dictionary. This dictionary will map each unique word in our dataset to a unique integer code.
#
# Additionally, we'll keep track of the frequency of each word, which will help us prioritize the most common words.

# %%
vocabulary_size = 50_000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)

# %% [markdown]
# ### Understanding the Key Variables
#
# - **`data`:** A list of integer codes representing the words in the original text. Each word is replaced by its corresponding code from the `dictionary`.
# - **`count`:** A list of tuples where each tuple contains a word and its frequency count in the dataset.
# - **`dictionary`:** A dictionary mapping each word to its unique integer code.
# - **`reverse_dictionary`:** A reverse mapping that converts integer codes back to their corresponding words.

# %%
del vocabulary # Reduce memory by getting rid of the "heavy" list of strings

# %%
data[:5] # An index of each word (as it appears in order) to its rank. Therefore we don't have reference the string
# Out:
# [5234, 3081, 12, 6, 195]

# %%
dictionary['the'] # word: rank
# Out:
# 1

# %%
reverse_dictionary[5234] # rank: word
# Out:
# 'anarchism'

# %%
print('Most common words:') 
print(*count[:5], sep="\n")
# Out:
# Most common words:
# ['UNK', 418391]
# ('the', 1061396)
# ('of', 593677)
# ('and', 416629)
# ('one', 411764)

# %%
print('Least common words:')
print(*count[-5:], sep="\n")
# Out:
# Least common words:
# ('codeword', 9)
# ('senussi', 9)
# ('unscr', 9)
# ('leonards', 9)
# ('hif', 9)

# %% [markdown]
# ### Step 3: Generate a Training Batch for the Skip-Gram Model
#
# In this step, we'll create a function to generate training batches for our skip-gram model. The skip-gram model is a variant of Word2Vec that predicts the context words given a target word. This function will help us prepare the data in the correct format for training the model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer[:] = data[:span]
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, 
                               num_skips=2, 
                               skip_window=1)

# %%
# Example of self-supervised learning
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of

# %% [markdown]
# ----
# Step 4: Build and train a skip-gram model.
# -----
#
# The Skip-Gram model is a type of neural network model used in Natural Language Processing (NLP) to learn distributed representations of words, commonly known as word embeddings.
#
# Word embeddings are dense vector representations of words that capture semantic relationships between them, meaning that words with similar meanings are mapped to similar points in the vector space.
#
# ### How the Skip-Gram Model Works
# The goal of the Skip-Gram model is to predict the context words given a target word. Here's how it works:
#
# Input: The model takes a single word (the target word) from the text as input.
#
# Output: The model is trained to predict words that are likely to appear in the context of the target word within a specified window of words before and after the target word. This context window is typically referred to as the "skip window."
#
# For example, if the sentence is "The cat sat on the mat," and the target word is "sat," the model might be asked to predict the words "The," "cat," "on," and "the," which appear around "sat."

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
import tensorflow.compat.v1 as v1

# %%
graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = v1.placeholder(tf.int32, shape=[batch_size])
    train_labels = v1.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = v1.constant(valid_examples, dtype=tf.int32)

    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            v1.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            v1.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Compute the average NCE loss for the batch.
        # tf.nce_loss automatically draws a new sample of the negative labels each
        # time we evaluate the loss.
        # Explanation of the meaning of NCE loss:
        #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
        loss = tf.reduce_mean(
          tf.nn.nce_loss(weights=nce_weights,
                         biases=nce_biases,
                         labels=train_labels,
                         inputs=embed,
                         num_sampled=num_sampled,
                         num_classes=vocabulary_size))

        # Construct the SGD optimizer using a learning rate of 1.0.
        optimizer = v1.train.GradientDescentOptimizer(1.0).minimize(loss)

        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(
          normalized_embeddings, valid_dataset)
        similarity = tf.matmul(
          valid_embeddings, normalized_embeddings, transpose_b=True)

        # Add variable initializer.
        init = v1.global_variables_initializer()
# Out:
# WARNING:tensorflow:From C:\Users\jurge\AppData\Local\Temp\ipykernel_18424\701590837.py:6: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\jurge\AppData\Local\Temp\ipykernel_18424\701590837.py:36: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.

# %% [markdown]
# ----
# Step 5: Begin training.
# -----

# %%
num_steps = 100_001 #1 #2_001 #100_001

with v1.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2_000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 2_000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 4 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to '%s':" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
            print()
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  302.4723815917969
# Nearest to 'up': kingship, aquino, agriculture, yn,
# Nearest to 'his': hsbc, kev, microorganism, crimea,
# Nearest to 'its': tablets, cheque, drava, aborigines,
# Nearest to 'called': legitimize, shou, willingly, indiscriminately,
# Nearest to 'between': stabilize, legalism, culmination, zorn,
# Nearest to 'he': condition, oersted, proxima, sanctuaries,
# Nearest to 'with': funerals, carver, crushing, cursive,
# Nearest to 'people': andorran, proprietors, patenting, serotonin,
# Nearest to 'first': piraeus, menstruation, hopped, shalmaneser,
# Nearest to 'one': slender, house, assigning, constellation,
# Nearest to 'no': rightist, jalalabad, tuner, ostensibly,
# Nearest to 'when': ammi, thematically, brezhnev, tumours,
# Nearest to 'states': logudorese, passers, kola, collapses,
# Nearest to 'five': luthiers, ideation, species, enco,
# Nearest to 'on': shadowrun, galicia, manatees, blitter,
# Nearest to 'about': genocide, babbitt, swap, memoir,
#
# Average loss at step  2000 :  113.22967797756195
# Nearest to 'up': agriculture, since, nothing, southern,
# Nearest to 'his': difference, december, works, rand,
# Nearest to 'its': jpg, culture, aborigines, make,
# Nearest to 'called': uk, colonies, nine, particular,
# Nearest to 'between': same, largest, institute, case,
# Nearest to 'he': divorce, opinion, opening, sq,
# Nearest to 'with': prominent, finish, legend, communicate,
# Nearest to 'people': andorran, anthropology, process, exclusively,
# Nearest to 'first': cause, either, territories, visual,
# Nearest to 'one': house, alien, the, UNK,
# Nearest to 'no': frankenstein, their, organizations, typically,
# Nearest to 'when': about, ascii, connected, times,
# Nearest to 'states': spelling, tortoise, now, only,
# Nearest to 'five': zero, nine, seven, species,
# Nearest to 'on': radar, finalist, strauss, majority,
# Nearest to 'about': six, when, concept, frame,
#
# Average loss at step  4000 :  53.09009883332253
# Nearest to 'up': agriculture, since, nothing, remained,
# Nearest to 'his': difference, december, asceticism, the,
# Nearest to 'its': agave, jpg, your, culture,
# Nearest to 'called': uk, colonies, grows, object,
# Nearest to 'between': same, agave, stabilize, case,
# Nearest to 'he': fao, opening, minutes, listed,
# Nearest to 'with': of, photoelectric, var, astronaut,
# Nearest to 'people': andorran, province, chlorine, anthropology,
# Nearest to 'first': either, cause, zero, visual,
# Nearest to 'one': tunnel, zero, hydrogen, house,
# Nearest to 'no': frankenstein, ostensibly, palestine, their,
# Nearest to 'when': ascii, elephant, connected, dominated,
# Nearest to 'states': fao, spelling, guns, tortoise,
# Nearest to 'five': zero, species, nine, seven,
# Nearest to 'on': of, in, voyage, radar,
# Nearest to 'about': six, frame, concept, when,
#
# Average loss at step  6000 :  33.03678887844086
# Nearest to 'up': agriculture, surprise, nothing, muslims,
# Nearest to 'his': the, a, UNK, difference,
# Nearest to 'its': jpg, initial, your, agave,
# Nearest to 'called': uk, object, colonies, toll,
# Nearest to 'between': same, stabilize, agave, zorn,
# Nearest to 'he': minutes, fao, opening, opinion,
# Nearest to 'with': photoelectric, migrant, of, into,
# Nearest to 'people': andorran, potato, province, exclusively,
# Nearest to 'first': either, cause, womb, visual,
# Nearest to 'one': zero, resemblance, tunnel, UNK,
# Nearest to 'no': rotate, frankenstein, ostensibly, their,
# Nearest to 'when': mosque, elephant, ascii, dominated,
# Nearest to 'states': fao, spelling, cc, guns,
# Nearest to 'five': zero, seven, nine, species,
# Nearest to 'on': of, in, mall, warriors,
# Nearest to 'about': genocide, six, concept, seventh,
#
# Average loss at step  8000 :  23.80283456611633
# Nearest to 'up': agriculture, nothing, surprise, since,
# Nearest to 'his': the, a, archie, difference,
# Nearest to 'its': the, initial, jpg, your,
# Nearest to 'called': uk, colonies, directed, object,
# Nearest to 'between': stabilize, same, zorn, agave,
# Nearest to 'he': bckgr, it, bipeds, they,
# Nearest to 'with': in, photoelectric, astronaut, into,
# Nearest to 'people': andorran, potato, province, mpa,
# Nearest to 'first': either, distinctly, phi, cause,
# Nearest to 'one': zero, archie, two, three,
# Nearest to 'no': aberdeenshire, rotate, frankenstein, wireless,
# Nearest to 'when': mosque, UNK, indivisible, ascii,
# Nearest to 'states': fao, spelling, cc, guns,
# Nearest to 'five': zero, nine, seven, mya,
# Nearest to 'on': in, of, sigma, voyage,
# Nearest to 'about': six, genocide, memoir, concept,
#
# Average loss at step  10000 :  17.600474518060683
# Nearest to 'up': agriculture, nothing, surprise, since,
# Nearest to 'his': the, a, s, archie,
# Nearest to 'its': the, anasazi, rectal, initial,
# Nearest to 'called': directed, toll, uk, grows,
# Nearest to 'between': stabilize, in, same, zorn,
# Nearest to 'he': it, bckgr, they, frisian,
# Nearest to 'with': in, and, of, into,
# Nearest to 'people': andorran, neurons, potato, mpa,
# Nearest to 'first': distinctly, either, phi, cause,
# Nearest to 'one': archie, two, nine, zero,
# Nearest to 'no': aberdeenshire, rotate, frankenstein, their,
# Nearest to 'when': mosque, ascii, indivisible, six,
# Nearest to 'states': fao, spelling, ix, cc,
# Nearest to 'five': zero, nine, seven, six,
# Nearest to 'on': in, of, and, to,
# Nearest to 'about': six, genocide, memoir, concept,
#
# Average loss at step  12000 :  14.270192101359367
# Nearest to 'up': agriculture, kingship, surprise, nothing,
# Nearest to 'his': the, homomorphism, a, s,
# Nearest to 'its': the, anasazi, rectal, your,
# Nearest to 'called': directed, colonies, foam, grows,
# Nearest to 'between': in, same, stabilize, zorn,
# Nearest to 'he': it, bckgr, they, three,
# Nearest to 'with': in, and, into, of,
# Nearest to 'people': andorran, potato, neurons, mpa,
# Nearest to 'first': piraeus, distinctly, either, phi,
# Nearest to 'one': two, archie, nine, zero,
# Nearest to 'no': aberdeenshire, that, wireless, their,
# Nearest to 'when': mosque, button, gollancz, ascii,
# Nearest to 'states': fao, spelling, ix, cc,
# Nearest to 'five': nine, zero, seven, two,
# Nearest to 'on': in, of, to, voyage,
# Nearest to 'about': six, genocide, memoir, concept,
#
# Average loss at step  14000 :  11.647338036894798
# Nearest to 'up': agriculture, kingship, circ, dasyprocta,
# Nearest to 'his': the, dasyprocta, homomorphism, a,
# Nearest to 'its': the, dasyprocta, anasazi, tablets,
# Nearest to 'called': directed, foam, grows, toll,
# Nearest to 'between': in, same, stabilize, zorn,
# Nearest to 'he': it, they, bckgr, frisian,
# Nearest to 'with': in, and, into, to,
# Nearest to 'people': andorran, neurons, potato, mpa,
# Nearest to 'first': piraeus, distinctly, dasyprocta, theatres,
# Nearest to 'one': circ, operatorname, dasyprocta, two,
# Nearest to 'no': aberdeenshire, that, wireless, agouti,
# Nearest to 'when': mosque, button, dasyprocta, gollancz,
# Nearest to 'states': fao, spelling, operatorname, ix,
# Nearest to 'five': zero, dasyprocta, nine, two,
# Nearest to 'on': in, circ, of, and,
# Nearest to 'about': six, agouti, memoir, genocide,
#
# Average loss at step  16000 :  10.169965819120407
# Nearest to 'up': agriculture, kingship, aquino, circ,
# Nearest to 'his': the, a, dasyprocta, homomorphism,
# Nearest to 'its': the, dasyprocta, anasazi, tablets,
# Nearest to 'called': and, directed, placebo, grows,
# Nearest to 'between': in, same, stabilize, and,
# Nearest to 'he': it, they, bckgr, sanctuaries,
# Nearest to 'with': in, and, into, by,
# Nearest to 'people': andorran, potato, neurons, mpa,
# Nearest to 'first': piraeus, distinctly, theatres, on,
# Nearest to 'one': operatorname, two, circ, dasyprocta,
# Nearest to 'no': aberdeenshire, wireless, that, their,
# Nearest to 'when': mosque, button, dasyprocta, gollancz,
# Nearest to 'states': fao, spelling, ix, operatorname,
# Nearest to 'five': zero, nine, two, seven,
# Nearest to 'on': in, circ, and, of,
# Nearest to 'about': six, nine, memoir, agouti,
#
# Average loss at step  18000 :  8.459017309427262
# Nearest to 'up': agriculture, kingship, aquino, circ,
# Nearest to 'his': the, their, a, dasyprocta,
# Nearest to 'its': the, their, dasyprocta, anasazi,
# Nearest to 'called': placebo, directed, grows, foam,
# Nearest to 'between': in, same, stabilize, nine,
# Nearest to 'he': it, they, who, bckgr,
# Nearest to 'with': in, and, into, by,
# Nearest to 'people': andorran, neurons, potato, proprietors,
# Nearest to 'first': piraeus, distinctly, theatres, dasyprocta,
# Nearest to 'one': operatorname, circ, dasyprocta, agouti,
# Nearest to 'no': aberdeenshire, that, wireless, their,
# Nearest to 'when': mosque, button, dasyprocta, gollancz,
# Nearest to 'states': fao, spelling, ix, operatorname,
# Nearest to 'five': seven, nine, two, zero,
# Nearest to 'on': in, circ, of, and,
# Nearest to 'about': six, memoir, treasury, agouti,
#
# Average loss at step  20000 :  7.970353802680969
# Nearest to 'up': kingship, agriculture, aquino, circ,
# Nearest to 'his': the, their, s, dasyprocta,
# Nearest to 'its': the, their, dasyprocta, this,
# Nearest to 'called': placebo, and, directed, UNK,
# Nearest to 'between': in, same, stabilize, and,
# Nearest to 'he': it, they, who, three,
# Nearest to 'with': in, and, of, by,
# Nearest to 'people': andorran, neurons, potato, mpa,
# Nearest to 'first': piraeus, distinctly, theatres, dasyprocta,
# Nearest to 'one': two, operatorname, eight, three,
# Nearest to 'no': that, aberdeenshire, wireless, their,
# Nearest to 'when': mosque, button, gollancz, arises,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': nine, seven, zero, eight,
# Nearest to 'on': in, circ, and, of,
# Nearest to 'about': six, agouti, memoir, treasury,
#
# Average loss at step  22000 :  7.016089605808258
# Nearest to 'up': kingship, agriculture, aquino, circ,
# Nearest to 'his': the, their, dasyprocta, a,
# Nearest to 'its': the, their, dasyprocta, this,
# Nearest to 'called': placebo, and, directed, foam,
# Nearest to 'between': in, same, stabilize, and,
# Nearest to 'he': it, they, who, three,
# Nearest to 'with': in, of, and, by,
# Nearest to 'people': andorran, neurons, proprietors, potato,
# Nearest to 'first': piraeus, distinctly, theatres, dasyprocta,
# Nearest to 'one': two, eight, operatorname, four,
# Nearest to 'no': that, aberdeenshire, wireless, libel,
# Nearest to 'when': mosque, five, button, arises,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': two, seven, zero, nine,
# Nearest to 'on': in, circ, two, of,
# Nearest to 'about': six, treasury, memoir, agouti,
#
# Average loss at step  24000 :  6.824828048706054
# Nearest to 'up': kingship, agriculture, aquino, circ,
# Nearest to 'his': the, their, her, dasyprocta,
# Nearest to 'its': the, their, dasyprocta, his,
# Nearest to 'called': placebo, and, directed, foam,
# Nearest to 'between': in, stabilize, same, irenaeus,
# Nearest to 'he': it, they, who, three,
# Nearest to 'with': in, and, by, for,
# Nearest to 'people': andorran, neurons, proprietors, mpa,
# Nearest to 'first': piraeus, distinctly, theatres, dasyprocta,
# Nearest to 'one': two, operatorname, five, eight,
# Nearest to 'no': aberdeenshire, that, wireless, agouti,
# Nearest to 'when': mosque, five, arises, after,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': nine, seven, zero, six,
# Nearest to 'on': in, circ, otimes, by,
# Nearest to 'about': six, treasury, memoir, agouti,
#
# Average loss at step  26000 :  6.737015279054642
# Nearest to 'up': kingship, agriculture, circ, aquino,
# Nearest to 'his': their, the, her, dasyprocta,
# Nearest to 'its': the, their, his, dasyprocta,
# Nearest to 'called': placebo, and, UNK, directed,
# Nearest to 'between': in, same, stabilize, by,
# Nearest to 'he': it, they, who, three,
# Nearest to 'with': in, by, and, into,
# Nearest to 'people': andorran, neurons, proprietors, diabelli,
# Nearest to 'first': piraeus, distinctly, theatres, dasyprocta,
# Nearest to 'one': two, eight, five, four,
# Nearest to 'no': that, aberdeenshire, wireless, their,
# Nearest to 'when': mosque, five, after, six,
# Nearest to 'states': fao, spelling, operatorname, ix,
# Nearest to 'five': seven, eight, six, four,
# Nearest to 'on': in, circ, otimes, two,
# Nearest to 'about': six, agouti, treasury, memoir,
#
# Average loss at step  28000 :  6.4768615682125095
# Nearest to 'up': kingship, agriculture, circ, aquino,
# Nearest to 'his': the, their, her, its,
# Nearest to 'its': the, their, his, dasyprocta,
# Nearest to 'called': placebo, and, UNK, directed,
# Nearest to 'between': in, stabilize, same, by,
# Nearest to 'he': it, they, who, she,
# Nearest to 'with': in, by, and, for,
# Nearest to 'people': andorran, neurons, proprietors, diabelli,
# Nearest to 'first': piraeus, distinctly, theatres, dasyprocta,
# Nearest to 'one': two, operatorname, eight, circ,
# Nearest to 'no': that, wireless, aberdeenshire, their,
# Nearest to 'when': mosque, after, arises, was,
# Nearest to 'states': fao, spelling, operatorname, ix,
# Nearest to 'five': seven, eight, six, nine,
# Nearest to 'on': in, circ, otimes, eight,
# Nearest to 'about': six, agouti, memoir, treasury,
#
# Average loss at step  30000 :  5.902194513916969
# Nearest to 'up': kingship, agriculture, circ, aquino,
# Nearest to 'his': their, the, her, its,
# Nearest to 'its': the, their, his, dasyprocta,
# Nearest to 'called': placebo, and, fortunes, directed,
# Nearest to 'between': in, stabilize, same, by,
# Nearest to 'he': it, they, who, she,
# Nearest to 'with': in, by, and, for,
# Nearest to 'people': andorran, proprietors, neurons, diabelli,
# Nearest to 'first': piraeus, theatres, distinctly, dasyprocta,
# Nearest to 'one': two, operatorname, four, three,
# Nearest to 'no': that, wireless, aberdeenshire, libel,
# Nearest to 'when': mosque, after, six, five,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': seven, six, eight, four,
# Nearest to 'on': in, circ, by, and,
# Nearest to 'about': six, agouti, memoir, treasury,
#
# Average loss at step  32000 :  6.006413380146027
# Nearest to 'up': kingship, agriculture, aquino, circ,
# Nearest to 'his': their, the, her, its,
# Nearest to 'its': the, their, his, dasyprocta,
# Nearest to 'called': placebo, fortunes, directed, and,
# Nearest to 'between': in, stabilize, same, irenaeus,
# Nearest to 'he': it, they, who, she,
# Nearest to 'with': in, by, and, for,
# Nearest to 'people': andorran, proprietors, neurons, diabelli,
# Nearest to 'first': piraeus, theatres, distinctly, dasyprocta,
# Nearest to 'one': two, four, seven, five,
# Nearest to 'no': wireless, aberdeenshire, that, agouti,
# Nearest to 'when': after, mosque, was, five,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': seven, six, eight, four,
# Nearest to 'on': in, circ, and, two,
# Nearest to 'about': six, treasury, agouti, memoir,
#
# Average loss at step  34000 :  5.714682418227196
# Nearest to 'up': kingship, agriculture, aquino, circ,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': the, their, his, dasyprocta,
# Nearest to 'called': placebo, UNK, and, fortunes,
# Nearest to 'between': in, stabilize, same, with,
# Nearest to 'he': it, they, who, she,
# Nearest to 'with': in, by, and, for,
# Nearest to 'people': andorran, proprietors, neurons, diabelli,
# Nearest to 'first': piraeus, theatres, distinctly, dasyprocta,
# Nearest to 'one': two, three, four, seven,
# Nearest to 'no': wireless, that, aberdeenshire, orchestra,
# Nearest to 'when': after, mosque, vma, before,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': four, seven, six, three,
# Nearest to 'on': in, circ, from, otimes,
# Nearest to 'about': six, agouti, treasury, memoir,
#
# Average loss at step  36000 :  5.793662365198135
# Nearest to 'up': kingship, agriculture, aquino, circ,
# Nearest to 'his': their, the, her, its,
# Nearest to 'its': the, their, his, dasyprocta,
# Nearest to 'called': and, placebo, UNK, directed,
# Nearest to 'between': in, stabilize, same, with,
# Nearest to 'he': it, they, who, she,
# Nearest to 'with': in, by, and, for,
# Nearest to 'people': andorran, proprietors, neurons, conscripted,
# Nearest to 'first': piraeus, theatres, distinctly, dasyprocta,
# Nearest to 'one': two, three, seven, four,
# Nearest to 'no': that, wireless, aberdeenshire, orchestra,
# Nearest to 'when': after, mosque, vma, five,
# Nearest to 'states': fao, spelling, operatorname, ix,
# Nearest to 'five': seven, four, six, three,
# Nearest to 'on': in, circ, from, at,
# Nearest to 'about': agouti, memoir, six, treasury,
#
# Average loss at step  38000 :  5.5111093308925625
# Nearest to 'up': kingship, agriculture, aquino, circ,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, the, his, dasyprocta,
# Nearest to 'called': placebo, and, or, directed,
# Nearest to 'between': in, with, stabilize, same,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': in, and, by, into,
# Nearest to 'people': andorran, proprietors, diabelli, neurons,
# Nearest to 'first': piraeus, theatres, distinctly, dasyprocta,
# Nearest to 'one': two, three, four, operatorname,
# Nearest to 'no': that, wireless, aberdeenshire, orchestra,
# Nearest to 'when': after, mosque, vma, was,
# Nearest to 'states': fao, spelling, ix, operatorname,
# Nearest to 'five': four, seven, six, three,
# Nearest to 'on': in, circ, from, at,
# Nearest to 'about': six, agouti, five, memoir,
#
# Average loss at step  40000 :  5.299165057420731
# Nearest to 'up': kingship, agriculture, aquino, circ,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, the, his, dasyprocta,
# Nearest to 'called': placebo, and, or, UNK,
# Nearest to 'between': in, stabilize, same, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': in, and, by, zero,
# Nearest to 'people': andorran, proprietors, neurons, diabelli,
# Nearest to 'first': piraeus, distinctly, theatres, ttir,
# Nearest to 'one': two, three, four, operatorname,
# Nearest to 'no': that, wireless, aberdeenshire, rightist,
# Nearest to 'when': after, mosque, before, vma,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': four, seven, six, three,
# Nearest to 'on': in, circ, from, at,
# Nearest to 'about': six, agouti, three, five,
#
# Average loss at step  42000 :  5.384428834676743
# Nearest to 'up': kingship, agriculture, aquino, circ,
# Nearest to 'his': their, the, its, her,
# Nearest to 'its': the, their, his, dasyprocta,
# Nearest to 'called': placebo, and, UNK, or,
# Nearest to 'between': in, stabilize, same, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': in, by, through, into,
# Nearest to 'people': andorran, proprietors, diabelli, neurons,
# Nearest to 'first': piraeus, distinctly, theatres, dasyprocta,
# Nearest to 'one': two, three, seven, four,
# Nearest to 'no': that, aberdeenshire, wireless, rightist,
# Nearest to 'when': after, before, mosque, though,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': six, four, seven, three,
# Nearest to 'on': in, circ, from, at,
# Nearest to 'about': six, agouti, memoir, treasury,
#
# Average loss at step  44000 :  5.279868845820427
# Nearest to 'up': kingship, agriculture, aquino, circ,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, the, his, dasyprocta,
# Nearest to 'called': and, placebo, shou, UNK,
# Nearest to 'between': in, stabilize, with, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': in, by, through, into,
# Nearest to 'people': andorran, proprietors, diabelli, neurons,
# Nearest to 'first': piraeus, distinctly, theatres, dasyprocta,
# Nearest to 'one': two, five, seven, six,
# Nearest to 'no': aberdeenshire, wireless, rightist, that,
# Nearest to 'when': after, before, mosque, vma,
# Nearest to 'states': fao, spelling, operatorname, ix,
# Nearest to 'five': six, four, three, seven,
# Nearest to 'on': in, circ, from, at,
# Nearest to 'about': six, agouti, memoir, five,
#
# Average loss at step  46000 :  5.216097965359688
# Nearest to 'up': kingship, agriculture, aquino, circ,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, the, his, dasyprocta,
# Nearest to 'called': and, UNK, placebo, directed,
# Nearest to 'between': in, with, stabilize, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': in, and, by, from,
# Nearest to 'people': andorran, proprietors, solicitation, diabelli,
# Nearest to 'first': piraeus, distinctly, last, dasyprocta,
# Nearest to 'one': two, four, five, six,
# Nearest to 'no': aberdeenshire, wireless, that, rightist,
# Nearest to 'when': after, mosque, before, vma,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': four, six, three, eight,
# Nearest to 'on': in, circ, from, at,
# Nearest to 'about': six, agouti, five, memoir,
#
# Average loss at step  48000 :  5.232400734305382
# Nearest to 'up': kingship, agriculture, aquino, circ,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, the, his, dasyprocta,
# Nearest to 'called': placebo, and, UNK, directed,
# Nearest to 'between': in, stabilize, with, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': in, by, and, into,
# Nearest to 'people': andorran, proprietors, solicitation, diabelli,
# Nearest to 'first': piraeus, last, distinctly, dasyprocta,
# Nearest to 'one': two, four, three, six,
# Nearest to 'no': aberdeenshire, rightist, wireless, that,
# Nearest to 'when': after, before, mosque, though,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': four, six, three, seven,
# Nearest to 'on': in, circ, two, from,
# Nearest to 'about': agouti, memoir, treasury, babbitt,
#
# Average loss at step  50000 :  5.018258589863777
# Nearest to 'up': kingship, agriculture, circ, aquino,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, the, his, dasyprocta,
# Nearest to 'called': placebo, and, UNK, shou,
# Nearest to 'between': in, stabilize, with, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': in, by, and, into,
# Nearest to 'people': andorran, solicitation, proprietors, diabelli,
# Nearest to 'first': piraeus, last, distinctly, second,
# Nearest to 'one': two, four, three, eight,
# Nearest to 'no': aberdeenshire, wireless, rightist, orchestra,
# Nearest to 'when': after, before, though, six,
# Nearest to 'states': fao, spelling, operatorname, ix,
# Nearest to 'five': four, six, three, seven,
# Nearest to 'on': in, circ, two, from,
# Nearest to 'about': agouti, memoir, six, treasury,
#
# Average loss at step  52000 :  5.038182521224022
# Nearest to 'up': kingship, agriculture, circ, aquino,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, the, his, dasyprocta,
# Nearest to 'called': and, placebo, directed, UNK,
# Nearest to 'between': in, with, stabilize, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': in, and, by, into,
# Nearest to 'people': solicitation, proprietors, andorran, diabelli,
# Nearest to 'first': last, piraeus, distinctly, dasyprocta,
# Nearest to 'one': two, eight, six, seven,
# Nearest to 'no': aberdeenshire, wireless, orchestra, a,
# Nearest to 'when': after, before, six, though,
# Nearest to 'states': fao, spelling, operatorname, ix,
# Nearest to 'five': four, six, three, seven,
# Nearest to 'on': in, circ, from, and,
# Nearest to 'about': agouti, memoir, treasury, five,
#
# Average loss at step  54000 :  5.173317811965942
# Nearest to 'up': kingship, circ, agriculture, aquino,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, the, his, dasyprocta,
# Nearest to 'called': and, placebo, UNK, directed,
# Nearest to 'between': in, with, stabilize, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': by, in, and, through,
# Nearest to 'people': proprietors, andorran, solicitation, diabelli,
# Nearest to 'first': last, piraeus, distinctly, final,
# Nearest to 'one': two, eight, six, three,
# Nearest to 'no': aberdeenshire, a, orchestra, now,
# Nearest to 'when': after, before, though, vma,
# Nearest to 'states': fao, spelling, operatorname, ix,
# Nearest to 'five': four, six, eight, three,
# Nearest to 'on': in, circ, at, from,
# Nearest to 'about': agouti, four, treasury, memoir,
#
# Average loss at step  56000 :  5.048946282505989
# Nearest to 'up': kingship, circ, agriculture, aquino,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, the, his, dasyprocta,
# Nearest to 'called': and, placebo, directed, shou,
# Nearest to 'between': in, with, stabilize, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': and, in, by, through,
# Nearest to 'people': proprietors, andorran, solicitation, diabelli,
# Nearest to 'first': last, piraeus, distinctly, second,
# Nearest to 'one': two, three, six, eight,
# Nearest to 'no': aberdeenshire, typically, orchestra, wireless,
# Nearest to 'when': after, before, though, mosque,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': four, six, three, eight,
# Nearest to 'on': in, circ, at, from,
# Nearest to 'about': agouti, treasury, memoir, babbitt,
#
# Average loss at step  58000 :  5.061364564657211
# Nearest to 'up': kingship, aquino, agriculture, gesta,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, his, the, dasyprocta,
# Nearest to 'called': placebo, and, directed, shou,
# Nearest to 'between': in, with, stabilize, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': in, by, and, between,
# Nearest to 'people': proprietors, andorran, solicitation, diabelli,
# Nearest to 'first': last, piraeus, distinctly, second,
# Nearest to 'one': two, six, eight, three,
# Nearest to 'no': aberdeenshire, typically, orchestra, wireless,
# Nearest to 'when': after, before, though, mosque,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': four, six, eight, three,
# Nearest to 'on': in, circ, at, from,
# Nearest to 'about': agouti, four, treasury, memoir,
#
# Average loss at step  60000 :  4.952490149140358
# Nearest to 'up': kingship, pulau, circ, aquino,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, his, the, dasyprocta,
# Nearest to 'called': placebo, and, directed, shou,
# Nearest to 'between': in, with, stabilize, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': in, between, by, and,
# Nearest to 'people': proprietors, andorran, solicitation, diabelli,
# Nearest to 'first': last, piraeus, distinctly, theron,
# Nearest to 'one': two, three, four, six,
# Nearest to 'no': aberdeenshire, orchestra, typically, rightist,
# Nearest to 'when': after, before, though, if,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': four, six, eight, three,
# Nearest to 'on': in, circ, at, from,
# Nearest to 'about': agouti, six, treasury, babbitt,
#
# Average loss at step  62000 :  5.0242304321527484
# Nearest to 'up': kingship, pulau, circ, aquino,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, his, the, dasyprocta,
# Nearest to 'called': placebo, and, directed, shou,
# Nearest to 'between': in, with, stabilize, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': in, by, between, and,
# Nearest to 'people': proprietors, andorran, solicitation, distinguishes,
# Nearest to 'first': last, piraeus, distinctly, second,
# Nearest to 'one': two, three, six, four,
# Nearest to 'no': aberdeenshire, orchestra, typically, agouti,
# Nearest to 'when': after, before, though, if,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': four, six, three, eight,
# Nearest to 'on': circ, in, from, at,
# Nearest to 'about': agouti, six, four, treasury,
#
# Average loss at step  64000 :  4.841420780360699
# Nearest to 'up': kingship, pulau, circ, aquino,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, his, the, dasyprocta,
# Nearest to 'called': placebo, and, UNK, directed,
# Nearest to 'between': in, with, stabilize, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': in, between, by, and,
# Nearest to 'people': proprietors, andorran, solicitation, diabelli,
# Nearest to 'first': last, piraeus, distinctly, second,
# Nearest to 'one': two, six, seven, four,
# Nearest to 'no': aberdeenshire, orchestra, typically, agouti,
# Nearest to 'when': after, before, though, if,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': four, six, three, eight,
# Nearest to 'on': in, circ, from, under,
# Nearest to 'about': agouti, four, six, five,
#
# Average loss at step  66000 :  4.601151917457581
# Nearest to 'up': kingship, pulau, circ, gesta,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, his, the, dasyprocta,
# Nearest to 'called': placebo, directed, UNK, inositol,
# Nearest to 'between': with, in, stabilize, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': between, in, by, into,
# Nearest to 'people': proprietors, andorran, solicitation, diabelli,
# Nearest to 'first': last, piraeus, second, distinctly,
# Nearest to 'one': two, six, seven, operatorname,
# Nearest to 'no': aberdeenshire, rightist, orchestra, typically,
# Nearest to 'when': after, before, though, while,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': four, six, eight, three,
# Nearest to 'on': in, circ, from, under,
# Nearest to 'about': four, agouti, five, six,
#
# Average loss at step  68000 :  4.982597301721573
# Nearest to 'up': kingship, pulau, circ, gesta,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, his, the, dasyprocta,
# Nearest to 'called': placebo, and, thaler, UNK,
# Nearest to 'between': with, in, stabilize, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': thaler, between, by, in,
# Nearest to 'people': proprietors, andorran, solicitation, distinguishes,
# Nearest to 'first': last, piraeus, second, distinctly,
# Nearest to 'one': two, six, four, seven,
# Nearest to 'no': aberdeenshire, rightist, orchestra, typically,
# Nearest to 'when': after, before, if, though,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': four, six, eight, three,
# Nearest to 'on': in, circ, upon, from,
# Nearest to 'about': four, agouti, ivorian, treasury,
#
# Average loss at step  70000 :  4.88013280582428
# Nearest to 'up': kingship, pulau, circ, them,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, his, the, dasyprocta,
# Nearest to 'called': placebo, and, thaler, directed,
# Nearest to 'between': with, in, stabilize, irenaeus,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': thaler, between, by, in,
# Nearest to 'people': proprietors, solicitation, andorran, conscripted,
# Nearest to 'first': last, second, piraeus, distinctly,
# Nearest to 'one': two, six, four, three,
# Nearest to 'no': mucus, aberdeenshire, rightist, typically,
# Nearest to 'when': after, before, though, if,
# Nearest to 'states': fao, operatorname, spelling, ix,
# Nearest to 'five': four, six, three, eight,
# Nearest to 'on': in, circ, from, upon,
# Nearest to 'about': four, agouti, ivorian, babbitt,
#
# Average loss at step  72000 :  4.755869155406952
# Nearest to 'up': kingship, pulau, circ, them,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': placebo, and, UNK, thaler,
# Nearest to 'between': with, in, irenaeus, through,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': thaler, between, in, by,
# Nearest to 'people': proprietors, andorran, distinguishes, solicitation,
# Nearest to 'first': last, piraeus, second, distinctly,
# Nearest to 'one': two, six, seven, three,
# Nearest to 'no': a, mucus, aberdeenshire, rightist,
# Nearest to 'when': after, before, though, if,
# Nearest to 'states': fao, operatorname, ix, spelling,
# Nearest to 'five': four, six, three, seven,
# Nearest to 'on': in, circ, from, upon,
# Nearest to 'about': four, agouti, ivorian, babbitt,
#
# Average loss at step  74000 :  4.780606216907501
# Nearest to 'up': kingship, them, pulau, circ,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': placebo, and, thaler, thz,
# Nearest to 'between': with, in, irenaeus, through,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': thaler, in, between, by,
# Nearest to 'people': proprietors, andorran, distinguishes, solicitation,
# Nearest to 'first': last, second, piraeus, distinctly,
# Nearest to 'one': two, six, four, seven,
# Nearest to 'no': mucus, a, aberdeenshire, typically,
# Nearest to 'when': after, though, before, if,
# Nearest to 'states': fao, operatorname, spelling, vdc,
# Nearest to 'five': four, six, three, seven,
# Nearest to 'on': in, circ, from, upon,
# Nearest to 'about': agouti, four, ivorian, babbitt,
#
# Average loss at step  76000 :  4.7332677737474445
# Nearest to 'up': kingship, pulau, them, circ,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': placebo, and, thaler, thz,
# Nearest to 'between': in, with, irenaeus, through,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': thaler, in, between, through,
# Nearest to 'people': proprietors, andorran, distinguishes, conscripted,
# Nearest to 'first': last, second, piraeus, distinctly,
# Nearest to 'one': six, seven, four, two,
# Nearest to 'no': a, mucus, aberdeenshire, typically,
# Nearest to 'when': after, before, though, if,
# Nearest to 'states': fao, operatorname, obadiah, auction,
# Nearest to 'five': four, six, three, seven,
# Nearest to 'on': in, circ, from, at,
# Nearest to 'about': agouti, four, ivorian, severus,
#
# Average loss at step  78000 :  4.792694274485111
# Nearest to 'up': kingship, pulau, them, circ,
# Nearest to 'his': their, its, her, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': placebo, and, landscaping, thaler,
# Nearest to 'between': with, in, through, irenaeus,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': between, thaler, in, by,
# Nearest to 'people': proprietors, andorran, conscripted, distinguishes,
# Nearest to 'first': last, second, piraeus, distinctly,
# Nearest to 'one': four, two, seven, six,
# Nearest to 'no': mucus, aberdeenshire, typically, rightist,
# Nearest to 'when': after, before, though, if,
# Nearest to 'states': fao, operatorname, vdc, spelling,
# Nearest to 'five': six, four, seven, three,
# Nearest to 'on': in, circ, at, upon,
# Nearest to 'about': agouti, four, six, ivorian,
#
# Average loss at step  80000 :  4.806962205648422
# Nearest to 'up': kingship, them, pulau, gesta,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': placebo, and, thaler, landscaping,
# Nearest to 'between': with, in, through, stabilize,
# Nearest to 'he': it, they, she, who,
# Nearest to 'with': between, by, in, thaler,
# Nearest to 'people': proprietors, andorran, conscripted, distinguishes,
# Nearest to 'first': last, second, piraeus, distinctly,
# Nearest to 'one': seven, two, six, four,
# Nearest to 'no': mucus, aberdeenshire, rightist, typically,
# Nearest to 'when': after, before, though, if,
# Nearest to 'states': fao, operatorname, vdc, spelling,
# Nearest to 'five': four, six, seven, eight,
# Nearest to 'on': circ, in, upon, at,
# Nearest to 'about': agouti, four, ivorian, priceless,
#
# Average loss at step  82000 :  4.754939952492714
# Nearest to 'up': kingship, them, pulau, gesta,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': placebo, and, thaler, considered,
# Nearest to 'between': with, in, from, through,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': thaler, between, in, by,
# Nearest to 'people': proprietors, conscripted, andorran, distinguishes,
# Nearest to 'first': last, second, piraeus, distinctly,
# Nearest to 'one': two, seven, six, four,
# Nearest to 'no': mucus, aberdeenshire, orchestra, bodhidharma,
# Nearest to 'when': after, before, though, if,
# Nearest to 'states': fao, operatorname, vdc, auction,
# Nearest to 'five': four, six, seven, eight,
# Nearest to 'on': circ, in, upon, from,
# Nearest to 'about': agouti, four, priceless, ivorian,
#
# Average loss at step  84000 :  4.773498191952705
# Nearest to 'up': kingship, them, pulau, gesta,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': placebo, and, thaler, considered,
# Nearest to 'between': with, in, through, from,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': between, by, thaler, in,
# Nearest to 'people': proprietors, conscripted, distinguishes, andorran,
# Nearest to 'first': last, second, piraeus, distinctly,
# Nearest to 'one': two, seven, six, three,
# Nearest to 'no': a, mucus, aberdeenshire, orchestra,
# Nearest to 'when': after, before, though, if,
# Nearest to 'states': fao, operatorname, vdc, auction,
# Nearest to 'five': four, six, seven, eight,
# Nearest to 'on': in, circ, upon, at,
# Nearest to 'about': agouti, four, priceless, six,
#
# Average loss at step  86000 :  4.765099392652512
# Nearest to 'up': kingship, them, pulau, gesta,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': and, placebo, thaler, considered,
# Nearest to 'between': with, in, from, through,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': in, by, between, thaler,
# Nearest to 'people': proprietors, conscripted, andorran, distinguishes,
# Nearest to 'first': last, second, piraeus, distinctly,
# Nearest to 'one': two, seven, four, six,
# Nearest to 'no': mucus, aberdeenshire, a, orchestra,
# Nearest to 'when': after, before, if, though,
# Nearest to 'states': fao, operatorname, vdc, spelling,
# Nearest to 'five': four, six, seven, eight,
# Nearest to 'on': in, circ, upon, at,
# Nearest to 'about': agouti, priceless, ivorian, four,
#
# Average loss at step  88000 :  4.746778864622116
# Nearest to 'up': kingship, them, pulau, gesta,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': placebo, and, considered, thaler,
# Nearest to 'between': with, in, from, through,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': between, thaler, by, in,
# Nearest to 'people': proprietors, conscripted, andorran, distinguishes,
# Nearest to 'first': last, second, piraeus, distinctly,
# Nearest to 'one': two, four, three, six,
# Nearest to 'no': mucus, aberdeenshire, typically, it,
# Nearest to 'when': after, before, if, though,
# Nearest to 'states': fao, operatorname, vdc, auction,
# Nearest to 'five': four, six, seven, eight,
# Nearest to 'on': in, circ, at, upon,
# Nearest to 'about': agouti, over, priceless, ivorian,
#
# Average loss at step  90000 :  4.723548037052154
# Nearest to 'up': kingship, them, pulau, gesta,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': and, placebo, considered, thaler,
# Nearest to 'between': with, in, from, through,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': between, thaler, by, in,
# Nearest to 'people': proprietors, conscripted, andorran, distinguishes,
# Nearest to 'first': last, second, piraeus, distinctly,
# Nearest to 'one': two, four, three, seven,
# Nearest to 'no': mucus, a, aberdeenshire, typically,
# Nearest to 'when': after, before, if, though,
# Nearest to 'states': fao, operatorname, auction, spelling,
# Nearest to 'five': four, seven, six, eight,
# Nearest to 'on': in, circ, upon, at,
# Nearest to 'about': agouti, over, priceless, severus,
#
# Average loss at step  92000 :  4.658824570417404
# Nearest to 'up': kingship, them, pulau, circ,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': and, placebo, UNK, considered,
# Nearest to 'between': with, in, from, through,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': between, thaler, in, by,
# Nearest to 'people': proprietors, conscripted, distinguishes, andorran,
# Nearest to 'first': last, second, piraeus, distinctly,
# Nearest to 'one': two, seven, eight, three,
# Nearest to 'no': mucus, aberdeenshire, typically, a,
# Nearest to 'when': after, before, if, though,
# Nearest to 'states': fao, operatorname, auction, vdc,
# Nearest to 'five': seven, eight, six, four,
# Nearest to 'on': in, circ, upon, at,
# Nearest to 'about': agouti, over, severus, priceless,
#
# Average loss at step  94000 :  4.720998926997185
# Nearest to 'up': them, kingship, pulau, gesta,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': placebo, and, considered, thaler,
# Nearest to 'between': with, in, through, from,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': in, between, thaler, by,
# Nearest to 'people': proprietors, conscripted, distinguishes, andorran,
# Nearest to 'first': last, second, piraeus, distinctly,
# Nearest to 'one': seven, two, four, six,
# Nearest to 'no': a, mucus, aberdeenshire, typically,
# Nearest to 'when': after, before, if, though,
# Nearest to 'states': fao, operatorname, auction, vdc,
# Nearest to 'five': seven, four, eight, six,
# Nearest to 'on': circ, in, upon, at,
# Nearest to 'about': agouti, over, priceless, severus,
#
# Average loss at step  96000 :  4.692499047279358
# Nearest to 'up': them, kingship, gesta, pulau,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': and, placebo, considered, thaler,
# Nearest to 'between': with, in, through, from,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': in, between, thaler, by,
# Nearest to 'people': proprietors, distinguishes, conscripted, solicitation,
# Nearest to 'first': last, second, piraeus, distinctly,
# Nearest to 'one': two, seven, four, six,
# Nearest to 'no': aberdeenshire, mucus, a, typically,
# Nearest to 'when': after, if, before, though,
# Nearest to 'states': fao, operatorname, auction, vdc,
# Nearest to 'five': seven, four, eight, six,
# Nearest to 'on': circ, in, upon, at,
# Nearest to 'about': agouti, over, priceless, severus,
#
# Average loss at step  98000 :  4.585168032824993
# Nearest to 'up': them, kingship, gesta, pulau,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': and, placebo, considered, inositol,
# Nearest to 'between': with, in, through, stabilize,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': between, thaler, in, by,
# Nearest to 'people': proprietors, solicitation, distinguishes, conscripted,
# Nearest to 'first': last, second, piraeus, next,
# Nearest to 'one': seven, two, six, eight,
# Nearest to 'no': mucus, aberdeenshire, typically, nine,
# Nearest to 'when': after, if, before, while,
# Nearest to 'states': fao, operatorname, auction, spelling,
# Nearest to 'five': four, seven, six, eight,
# Nearest to 'on': in, circ, upon, around,
# Nearest to 'about': agouti, three, over, four,
#
# Average loss at step  100000 :  4.695617267727852
# Nearest to 'up': them, kingship, gesta, pulau,
# Nearest to 'his': their, her, its, the,
# Nearest to 'its': their, his, the, her,
# Nearest to 'called': and, placebo, considered, inositol,
# Nearest to 'between': with, in, through, from,
# Nearest to 'he': it, she, they, who,
# Nearest to 'with': between, thaler, in, through,
# Nearest to 'people': proprietors, solicitation, distinguishes, conscripted,
# Nearest to 'first': last, second, piraeus, next,
# Nearest to 'one': six, two, seven, four,
# Nearest to 'no': nine, mucus, aberdeenshire, orchestra,
# Nearest to 'when': after, if, before, while,
# Nearest to 'states': fao, operatorname, auction, vdc,
# Nearest to 'five': four, seven, three, eight,
# Nearest to 'on': circ, in, upon, around,
# Nearest to 'about': agouti, runic, over, three,

# %% [markdown]
# <center><img src="../images/watiing.jpg" width="700"/></center>

# %% [markdown]
# -----
# Step 6: Visualize the embeddings with t-SNE.
# ----

# %% [markdown]
# In this step, we use the t-SNE algorithm to reduce the dimensionality of the learned word embeddings for visualization.
#
# The top 500 words (based on frequency) are plotted in a 2D space, allowing us to visually inspect the relationships and groupings among words.
#
# This visualization is a powerful tool to understand how well the model has learned semantic relationships.

# %%
tsne = TSNE(perplexity=30, 
            n_components=2, 
            init='pca', 
            n_iter=5_000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]

n_words_to_visualize = 40

for i, label in enumerate(labels[:n_words_to_visualize]):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %% [markdown]
# ------
#
# # Let's render and plot more samples.

# %%
def plot_with_labels(low_dim_embs, labels, filename='../images/tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels)

# %% [markdown]
# # And voila!
#
# Now you have a visual understanding of embeddings.

# %% [markdown]
# Thank you for following this tutorial!
